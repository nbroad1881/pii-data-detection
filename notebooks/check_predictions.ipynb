# %%
import pandas as pd

pd.options.display.max_rows = 999

df = pd.read_csv("/drive2/kaggle/pii-dd/piidd/training/basic/d3l_{8e-5}_{4}/20240220030113_pii_fbeta.csv", engine="python")

df["label_gt"].fillna("FP", inplace=True)

# %%
df.groupby(["label_gt", "cm"], dropna=False).count()
# Out:
#                        Unnamed: 0  token  label_pred  document  \
# label_gt         cm
# B-EMAIL          TP            11     11          11        11
# B-ID_NUM         FN             1      1           0         1
#                  FNFP           2      2           2         2
#                  TP            21     21          21        21
# B-NAME_STUDENT   FN            65     65           0        65
#                  TP           274    274         274       274
# B-PHONE_NUM      TP             4      4           4         4
# B-STREET_ADDRESS TP             1      1           1         1
# B-URL_PERSONAL   TP            15     15          15        15
# B-USERNAME       TP             1      1           1         1
# FP               FP            71     71          71        71
# I-NAME_STUDENT   FN            14     14           0        14
#                  FNFP           1      1           1         1
#                  TP           247    247         247       247
# I-PHONE_NUM      TP            12     12          12        12
# I-STREET_ADDRESS FN             1      1           0         1
#                  TP             9      9           9         9
#
#                        token_text_pred  row_id_pred  token_text_gt  row_id_gt
# label_gt         cm
# B-EMAIL          TP                 11           11             11         11
# B-ID_NUM         FN                  0            0              1          1
#                  FNFP                2            2              2          2
#                  TP                 21           21             21         21
# B-NAME_STUDENT   FN                  0            0             65         65
#                  TP                274          274            274        274
# B-PHONE_NUM      TP                  4            4              4          4
# B-STREET_ADDRESS TP                  1            1              1          1
# B-URL_PERSONAL   TP                 15           15             15         15
# B-USERNAME       TP                  1            1              1          1
# FP               FP                 71           71              0          0
# I-NAME_STUDENT   FN                  0            0             14         14
#                  FNFP                1            1              1          1
#                  TP                247          247            247        247
# I-PHONE_NUM      TP                 12           12             12         12
# I-STREET_ADDRESS FN                  0            0              1          1
#                  TP                  9            9              9          9

# %%
df[df["cm"]=="FN"]
# Out:
#      Unnamed: 0  token label_pred  document token_text_pred  row_id_pred  \
# 669         669   1719        NaN     11073             NaN          NaN
# 670         670   1734        NaN     11073             NaN          NaN
# 671         671   1750        NaN     11073             NaN          NaN
# 672         672    730        NaN      9674             NaN          NaN
# 673         673    735        NaN      9674             NaN          NaN
# 674         674    741        NaN      9674             NaN          NaN
# 675         675     63        NaN      3885             NaN          NaN
# 676         676    153        NaN      3885             NaN          NaN
# 677         677    172        NaN      3885             NaN          NaN
# 678         678    303        NaN      3885             NaN          NaN
# 679         679    409        NaN      3885             NaN          NaN
# 680         680    411        NaN      3885             NaN          NaN
# 681         681    417        NaN      3885             NaN          NaN
# 682         682      9        NaN     11421             NaN          NaN
# 683         683     10        NaN     11421             NaN          NaN
# 684         684     13        NaN       324             NaN          NaN
# 685         685    191        NaN      8108             NaN          NaN
# 686         686    529        NaN      8798             NaN          NaN
# 687         687    299        NaN      6591             NaN          NaN
# 688         688    106        NaN      6557             NaN          NaN
# 689         689    156        NaN     11442             NaN          NaN
# 690         690      3        NaN      5902             NaN          NaN
# 691         691      6        NaN     20984             NaN          NaN
# 692         692    125        NaN       609             NaN          NaN
# 693         693     13        NaN     11308             NaN          NaN
# 694         694    287        NaN     13249             NaN          NaN
# 695         695    349        NaN     13249             NaN          NaN
# 696         696    369        NaN     13249             NaN          NaN
# 697         697    396        NaN     13249             NaN          NaN
# 698         698    442        NaN     13249             NaN          NaN
# 699         699    451        NaN     13249             NaN          NaN
# 700         700    516        NaN     13249             NaN          NaN
# 701         701    570        NaN     13249             NaN          NaN
# 702         702    766        NaN     13249             NaN          NaN
# 703         703    839        NaN     13249             NaN          NaN
# 704         704    873        NaN     13249             NaN          NaN
# 705         705    881        NaN     13249             NaN          NaN
# 706         706    926        NaN     13249             NaN          NaN
# 707         707    947        NaN     13249             NaN          NaN
# 708         708    958        NaN     13249             NaN          NaN
# 709         709    964        NaN     13249             NaN          NaN
# 710         710    969        NaN     13249             NaN          NaN
# 711         711    983        NaN     13249             NaN          NaN
# 712         712   1009        NaN     13249             NaN          NaN
# 713         713   1024        NaN     13249             NaN          NaN
# 714         714    286        NaN      4161             NaN          NaN
# 715         715     35        NaN      5263             NaN          NaN
# 716         716     36        NaN      5263             NaN          NaN
# 717         717    540        NaN      7779             NaN          NaN
# 718         718    588        NaN      7779             NaN          NaN
# 719         719    589        NaN      7779             NaN          NaN
# 720         720    634        NaN      7779             NaN          NaN
# 721         721    653        NaN      7779             NaN          NaN
# 722         722    654        NaN      7779             NaN          NaN
# 723         723    740        NaN      7779             NaN          NaN
# 724         724    741        NaN      7779             NaN          NaN
# 725         725    754        NaN      7779             NaN          NaN
# 726         726    755        NaN      7779             NaN          NaN
# 727         727    823        NaN      7779             NaN          NaN
# 728         728    824        NaN      7779             NaN          NaN
# 729         729    497        NaN      9405             NaN          NaN
# 730         730    554        NaN      9405             NaN          NaN
# 731         731    575        NaN      9405             NaN          NaN
# 732         732    597        NaN      9405             NaN          NaN
# 733         733    620        NaN      9405             NaN          NaN
# 734         734    647        NaN      9405             NaN          NaN
# 735         735    668        NaN      9405             NaN          NaN
# 736         736    693        NaN      9405             NaN          NaN
# 737         737    704        NaN      9405             NaN          NaN
# 738         738    725        NaN      9405             NaN          NaN
# 739         739    745        NaN      9405             NaN          NaN
# 740         740    777        NaN      9405             NaN          NaN
# 741         741    819        NaN      9405             NaN          NaN
# 742         742    179        NaN      5215             NaN          NaN
# 743         743    203        NaN      5215             NaN          NaN
# 744         744    220        NaN      5215             NaN          NaN
# 745         745    248        NaN      5215             NaN          NaN
# 746         746    275        NaN      5215             NaN          NaN
# 747         747      6        NaN      6976             NaN          NaN
# 748         748    785        NaN      6976             NaN          NaN
# 749         749    786        NaN      6976             NaN          NaN
#
#              label_gt token_text_gt  row_id_gt  cm
# 669    B-NAME_STUDENT           Kim       10.0  FN
# 670    B-NAME_STUDENT           Kim       11.0  FN
# 671    B-NAME_STUDENT           Kim       12.0  FN
# 672    B-NAME_STUDENT      Princess       29.0  FN
# 673    B-NAME_STUDENT      Princess       30.0  FN
# 674    B-NAME_STUDENT      Princess       31.0  FN
# 675    B-NAME_STUDENT         Irina       39.0  FN
# 676    B-NAME_STUDENT         Irina       41.0  FN
# 677    B-NAME_STUDENT         Irina       42.0  FN
# 678    B-NAME_STUDENT          Luca       43.0  FN
# 679    B-NAME_STUDENT         Irina       44.0  FN
# 680    B-NAME_STUDENT          Luca       45.0  FN
# 681    B-NAME_STUDENT          Luca       46.0  FN
# 682    B-NAME_STUDENT          Borz      117.0  FN
# 683    I-NAME_STUDENT        Melnik      118.0  FN
# 684    B-NAME_STUDENT           Zia      171.0  FN
# 685    B-NAME_STUDENT         Sameh      175.0  FN
# 686    B-NAME_STUDENT       Roberta      219.0  FN
# 687    I-NAME_STUDENT         Dubey      252.0  FN
# 688    B-NAME_STUDENT          Luca      277.0  FN
# 689  I-STREET_ADDRESS            \n      284.0  FN
# 690    B-NAME_STUDENT         Karen      301.0  FN
# 691          B-ID_NUM        V69230      343.0  FN
# 692    B-NAME_STUDENT      Hlengiwe      397.0  FN
# 693    B-NAME_STUDENT          Flor      418.0  FN
# 694    B-NAME_STUDENT         David      511.0  FN
# 695    B-NAME_STUDENT         David      513.0  FN
# 696    B-NAME_STUDENT         David      514.0  FN
# 697    B-NAME_STUDENT         David      515.0  FN
# 698    B-NAME_STUDENT     Cristiane      516.0  FN
# 699    B-NAME_STUDENT     Cristiane      517.0  FN
# 700    B-NAME_STUDENT     Cristiane      518.0  FN
# 701    B-NAME_STUDENT     Cristiane      519.0  FN
# 702    B-NAME_STUDENT         David      520.0  FN
# 703    B-NAME_STUDENT     Cristiane      521.0  FN
# 704    B-NAME_STUDENT     Cristiane      522.0  FN
# 705    B-NAME_STUDENT     Cristiane      523.0  FN
# 706    B-NAME_STUDENT     Cristiane      524.0  FN
# 707    B-NAME_STUDENT         David      525.0  FN
# 708    B-NAME_STUDENT         David      526.0  FN
# 709    B-NAME_STUDENT         David      527.0  FN
# 710    B-NAME_STUDENT         David      528.0  FN
# 711    B-NAME_STUDENT     Cristiane      529.0  FN
# 712    B-NAME_STUDENT     Cristiane      530.0  FN
# 713    B-NAME_STUDENT         David      531.0  FN
# 714    B-NAME_STUDENT        Ashley      562.0  FN
# 715    B-NAME_STUDENT           Dla      584.0  FN
# 716    I-NAME_STUDENT         Xalid      585.0  FN
# 717    B-NAME_STUDENT         Leroy      591.0  FN
# 718    B-NAME_STUDENT      Sullivan      592.0  FN
# 719    I-NAME_STUDENT         Leroy      593.0  FN
# 720    B-NAME_STUDENT         Leroy      594.0  FN
# 721    B-NAME_STUDENT      Sullivan      595.0  FN
# 722    I-NAME_STUDENT         Leroy      596.0  FN
# 723    B-NAME_STUDENT      Sullivan      597.0  FN
# 724    I-NAME_STUDENT         Leroy      598.0  FN
# 725    B-NAME_STUDENT      Sullivan      599.0  FN
# 726    I-NAME_STUDENT         Leroy      600.0  FN
# 727    B-NAME_STUDENT      Sullivan      601.0  FN
# 728    I-NAME_STUDENT         Leroy      602.0  FN
# 729    B-NAME_STUDENT      Fabrizio      619.0  FN
# 730    B-NAME_STUDENT      Fabrizio      621.0  FN
# 731    B-NAME_STUDENT      Fabrizio      622.0  FN
# 732    B-NAME_STUDENT      Fabrizio      623.0  FN
# 733    B-NAME_STUDENT      Fabrizio      624.0  FN
# 734    B-NAME_STUDENT      Fabrizio      625.0  FN
# 735    B-NAME_STUDENT      Fabrizio      626.0  FN
# 736    B-NAME_STUDENT      Fabrizio      627.0  FN
# 737    B-NAME_STUDENT      Fabrizio      628.0  FN
# 738    B-NAME_STUDENT      Fabrizio      629.0  FN
# 739    B-NAME_STUDENT      Fabrizio      630.0  FN
# 740    B-NAME_STUDENT      Fabrizio      631.0  FN
# 741    B-NAME_STUDENT      Fabrizio      632.0  FN
# 742    I-NAME_STUDENT        Kumari      649.0  FN
# 743    I-NAME_STUDENT        Kumari      651.0  FN
# 744    I-NAME_STUDENT        Kumari      653.0  FN
# 745    I-NAME_STUDENT        Kumari      655.0  FN
# 746    I-NAME_STUDENT        Kumari      657.0  FN
# 747    B-NAME_STUDENT        Ifeoma      669.0  FN
# 748    B-NAME_STUDENT        Ifeoma      671.0  FN
# 749    I-NAME_STUDENT         Kings      672.0  FN

# %%
df[df["cm"]=="FP"]
# Out:
#      Unnamed: 0  token      label_pred  document  \
# 26           26    686  B-NAME_STUDENT      9674
# 27           27    688  I-NAME_STUDENT      9674
# 32           32    650        B-ID_NUM      5628
# 73           73    131  B-NAME_STUDENT     21345
# 74           74   1289  B-NAME_STUDENT     21345
# 117         117    971  B-NAME_STUDENT     19104
# 118         118    972  I-NAME_STUDENT     19104
# 119         119   1068  B-NAME_STUDENT     19104
# 131         131      0  I-NAME_STUDENT     20405
# 168         168    310  B-NAME_STUDENT      8108
# 169         169    383  B-NAME_STUDENT      8108
# 178         178     47  B-NAME_STUDENT      6718
# 229         229    535  B-NAME_STUDENT      8875
# 241         241    297  B-NAME_STUDENT     20370
# 258         258    205        B-ID_NUM      4717
# 259         259    337        B-ID_NUM      4717
# 262         262   1361  B-NAME_STUDENT     11261
# 263         263   1395  B-NAME_STUDENT     11261
# 264         264     10  B-NAME_STUDENT     22023
# 265         265     11  I-NAME_STUDENT     22023
# 266         266    561  B-NAME_STUDENT     22023
# 267         267    562  I-NAME_STUDENT     22023
# 302         302    177  B-URL_PERSONAL     16684
# 331         331     91  B-NAME_STUDENT     19469
# 332         332    153  B-NAME_STUDENT     19469
# 333         333    188  B-NAME_STUDENT     19469
# 468         468     12  B-NAME_STUDENT      9629
# 469         469     13  I-NAME_STUDENT      9629
# 470         470    509  B-NAME_STUDENT      9629
# 504         504    235  B-NAME_STUDENT     15045
# 505         505    382  B-NAME_STUDENT     15045
# 506         506    454  B-NAME_STUDENT     15045
# 561         561    618  I-NAME_STUDENT      1290
# 562         562    627  I-NAME_STUDENT      1290
# 570         570    200  B-NAME_STUDENT     16741
# 593         593    449  B-NAME_STUDENT     13047
# 609         609    621  B-NAME_STUDENT     11856
# 656         656      9  B-NAME_STUDENT      8842
# 657         657     10  I-NAME_STUDENT      8842
#
#                   token_text_pred  row_id_pred label_gt token_text_gt  \
# 26                         Alicia         26.0       FP           NaN
# 27                         Durand         27.0       FP           NaN
# 32                          Tapez         32.0       FP           NaN
# 73                           Ravi         73.0       FP           NaN
# 74                           Ravi         74.0       FP           NaN
# 117                       Anthony        117.0       FP           NaN
# 118                       Johnson        118.0       FP           NaN
# 119                       Anthony        119.0       FP           NaN
# 131                       Cousera        131.0       FP           NaN
# 168                         Vikas        168.0       FP           NaN
# 169                         Vikas        169.0       FP           NaN
# 178                           Rob        178.0       FP           NaN
# 229                         Seema        229.0       FP           NaN
# 241                          Raid        241.0       FP           NaN
# 258                  221910309005        258.0       FP           NaN
# 259                  221910309006        259.0       FP           NaN
# 262                         Belén        262.0       FP           NaN
# 263                         Belén        263.0       FP           NaN
# 264                         Vinay        264.0       FP           NaN
# 265                        Kolusu        265.0       FP           NaN
# 266                         Vinay        266.0       FP           NaN
# 267                        Kolusu        267.0       FP           NaN
# 302  https://youtu.be/LyaUS2PNiVQ        302.0       FP           NaN
# 331                          Bayo        331.0       FP           NaN
# 332                          Bayo        332.0       FP           NaN
# 333                          Bayo        333.0       FP           NaN
# 468                         Maria        468.0       FP           NaN
# 469                          Amin        469.0       FP           NaN
# 470                       Valerie        470.0       FP           NaN
# 504                          Sara        504.0       FP           NaN
# 505                          Sara        505.0       FP           NaN
# 506                          Sara        506.0       FP           NaN
# 561                         Bello        561.0       FP           NaN
# 562                         Bello        562.0       FP           NaN
# 570                      E’manuel        570.0       FP           NaN
# 593                       ​Sarah​        593.0       FP           NaN
# 609                         Geoff        609.0       FP           NaN
# 656                         Elisa        656.0       FP           NaN
# 657                        Ingram        657.0       FP           NaN
#
#      row_id_gt  cm
# 26         NaN  FP
# 27         NaN  FP
# 32         NaN  FP
# 73         NaN  FP
# 74         NaN  FP
# 117        NaN  FP
# 118        NaN  FP
# 119        NaN  FP
# 131        NaN  FP
# 168        NaN  FP
# 169        NaN  FP
# 178        NaN  FP
# 229        NaN  FP
# 241        NaN  FP
# 258        NaN  FP
# 259        NaN  FP
# 262        NaN  FP
# 263        NaN  FP
# 264        NaN  FP
# 265        NaN  FP
# 266        NaN  FP
# 267        NaN  FP
# 302        NaN  FP
# 331        NaN  FP
# 332        NaN  FP
# 333        NaN  FP
# 468        NaN  FP
# 469        NaN  FP
# 470        NaN  FP
# 504        NaN  FP
# 505        NaN  FP
# 506        NaN  FP
# 561        NaN  FP
# 562        NaN  FP
# 570        NaN  FP
# 593        NaN  FP
# 609        NaN  FP
# 656        NaN  FP
# 657        NaN  FP

# %%
df[df["cm"]=="FNFP"]
# Out:
#      Unnamed: 0  token label_pred  document token_text_pred  row_id_pred  \
# 114         114     55   B-ID_NUM     19280        30407059        114.0
#
#      label_gt token_text_gt  row_id_gt    cm
# 114  I-ID_NUM      30407059      104.0  FNFP

# %%
df["label"] = df["label_pred"]
df["row_id"] = df["row_id_pred"]

# %%
def correct_preds(pred_df):

    new_labels = []

    for d in pred_df["document"].unique():

        filtered = pred_df[pred_df["document"] == d].reset_index(drop=True)

        if len(filtered) > 0:
            filtered = filtered.sort_values("token", ascending=True)


            for idx, (doc_idx, pred_label, row_id) in enumerate(filtered[["token", "label", "row_id"]].values):
                if pred_label == "I-NAME_STUDENT":
                    if idx == 0:
                        new_labels.append((row_id, "B-NAME_STUDENT"))
                    else:
                        # if the previous token is not next to this token (by token id)
                        # OR if the label i
                        if filtered["token"][idx-1] != doc_idx -1 or filtered["label"][idx-1] not in {"B-NAME_STUDENT", "I-NAME_STUDENT"}:
                            new_labels.append((row_id, "B-NAME_STUDENT"))
    
    for (row_id, new_label) in new_labels:
        pred_df.loc[pred_df["row_id"] == row_id, "label"] = new_label

    return pred_df


correct_preds(df)
# Out:
#       Unnamed: 0  token      label_pred  document   token_text_pred  \
# 0              0     18  B-NAME_STUDENT      8699             Rosli
# 1              1    170  B-NAME_STUDENT      8699            Jeanne
# 2              2    171  I-NAME_STUDENT      8699           Liedtka
# 3              3    173  B-NAME_STUDENT      8699               Tim
# 4              4    507  B-NAME_STUDENT      8699            Daniel
# ...          ...    ...             ...       ...               ...
# 1078        1078      2  B-NAME_STUDENT     11859             Nurul
# 1079        1079      3  I-NAME_STUDENT     11859           Mohamed
# 1080        1080      7         B-EMAIL     11859  jray@hotmail.com
# 1081        1081    498             NaN     10517               NaN
# 1082        1082    366             NaN      9911               NaN
#
#       row_id_pred        label_gt     token_text_gt  row_id_gt  cm  \
# 0             0.0  B-NAME_STUDENT             Rosli        0.0  TP
# 1             1.0              FP               NaN        NaN  FP
# 2             2.0              FP               NaN        NaN  FP
# 3             3.0              FP               NaN        NaN  FP
# 4             4.0              FP               NaN        NaN  FP
# ...           ...             ...               ...        ...  ..
# 1078       1078.0  B-NAME_STUDENT             Nurul      724.0  TP
# 1079       1079.0  I-NAME_STUDENT           Mohamed      725.0  TP
# 1080       1080.0         B-EMAIL  jray@hotmail.com      726.0  TP
# 1081          NaN        B-ID_NUM             ras21       22.0  FN
# 1082          NaN  I-NAME_STUDENT            Mpanza      596.0  FN
#
#                label  row_id
# 0     B-NAME_STUDENT     0.0
# 1     B-NAME_STUDENT     1.0
# 2     I-NAME_STUDENT     2.0
# 3     B-NAME_STUDENT     3.0
# 4     B-NAME_STUDENT     4.0
# ...              ...     ...
# 1078  B-NAME_STUDENT  1078.0
# 1079  I-NAME_STUDENT  1079.0
# 1080         B-EMAIL  1080.0
# 1081             NaN     NaN
# 1082             NaN     NaN
#
# [1083 rows x 12 columns]

# %%
df[df["label"] != df["label_pred"]]
# Out:
#       Unnamed: 0  token      label_pred  document token_text_pred  \
# 5              5    509  I-NAME_STUDENT      8699          Joseph
# 13            13      3  I-NAME_STUDENT      7745      Savitribai
# 20            20    907  I-NAME_STUDENT      7745      Savitribai
# 25            25   1845  I-NAME_STUDENT      7745      Savitribai
# 29            29   2462  I-NAME_STUDENT      7745          Daniel
# 203          203   2015  I-NAME_STUDENT      9297         Liedtka
# 207          207    647  I-NAME_STUDENT      8584            Geoﬀ
# 289          289     92  I-NAME_STUDENT     13336          Thomas
# 294          294    417  I-NAME_STUDENT     13336          Thomas
# 295          295    436  I-NAME_STUDENT     13336          Thomas
# 298          298    615  I-NAME_STUDENT     13336          Thomas
# 322          322    201  I-NAME_STUDENT      9043         Manuela
# 358          358     43  I-NAME_STUDENT     14267         Beckler
# 365          365    218  I-NAME_STUDENT     14267         Beckler
# 371          371    430  I-NAME_STUDENT     14267            Carr
# 372          372    433  I-NAME_STUDENT     14267           Davis
# 374          374    479  I-NAME_STUDENT     14267            John
# 378          378    502  I-NAME_STUDENT     14267         Beckler
# 381          381    588  I-NAME_STUDENT     14267           Davis
# 383          383    843  I-NAME_STUDENT     14267            Carr
# 384          384    845  I-NAME_STUDENT     14267           Davis
# 431          431    338  I-NAME_STUDENT     11827        Semillas
# 477          477     12  I-NAME_STUDENT      9543         Thulani
# 547          547      3  I-NAME_STUDENT     11461         kitchen
# 602          602    280  I-NAME_STUDENT     10720       McConnell
# 610          610     22  I-NAME_STUDENT     13353    Visvesvaraya
# 717          717    842  I-NAME_STUDENT     13627        Chausova
# 718          718    849  I-NAME_STUDENT     13627       Malysheva
# 720          720    423  I-NAME_STUDENT     10175      J.Palacios
# 746          746    138  I-NAME_STUDENT      9493           Water
# 753          753    429  I-NAME_STUDENT      9493           Water
# 754          754    441  I-NAME_STUDENT      9493           Water
# 829          829    792  I-NAME_STUDENT     12512           Jordi
# 937          937     24  I-NAME_STUDENT      8575        Sobyanin
# 1020        1020     13  I-NAME_STUDENT     11942          Darden
# 1081        1081    498             NaN     10517             NaN
# 1082        1082    366             NaN      9911             NaN
#
#       row_id_pred        label_gt token_text_gt  row_id_gt    cm  \
# 5             5.0              FP           NaN        NaN    FP
# 13           13.0              FP           NaN        NaN    FP
# 20           20.0              FP           NaN        NaN    FP
# 25           25.0              FP           NaN        NaN    FP
# 29           29.0  B-NAME_STUDENT        Daniel       13.0  FNFP
# 203         203.0              FP           NaN        NaN    FP
# 207         207.0              FP           NaN        NaN    FP
# 289         289.0              FP           NaN        NaN    FP
# 294         294.0              FP           NaN        NaN    FP
# 295         295.0              FP           NaN        NaN    FP
# 298         298.0              FP           NaN        NaN    FP
# 322         322.0  B-NAME_STUDENT       Manuela      218.0  FNFP
# 358         358.0              FP           NaN        NaN    FP
# 365         365.0              FP           NaN        NaN    FP
# 371         371.0              FP           NaN        NaN    FP
# 372         372.0              FP           NaN        NaN    FP
# 374         374.0              FP           NaN        NaN    FP
# 378         378.0              FP           NaN        NaN    FP
# 381         381.0              FP           NaN        NaN    FP
# 383         383.0              FP           NaN        NaN    FP
# 384         384.0              FP           NaN        NaN    FP
# 431         431.0              FP           NaN        NaN    FP
# 477         477.0  B-NAME_STUDENT       Thulani      300.0  FNFP
# 547         547.0              FP           NaN        NaN    FP
# 602         602.0              FP           NaN        NaN    FP
# 610         610.0              FP           NaN        NaN    FP
# 717         717.0              FP           NaN        NaN    FP
# 718         718.0              FP           NaN        NaN    FP
# 720         720.0              FP           NaN        NaN    FP
# 746         746.0              FP           NaN        NaN    FP
# 753         753.0              FP           NaN        NaN    FP
# 754         754.0              FP           NaN        NaN    FP
# 829         829.0  B-NAME_STUDENT         Jordi      535.0  FNFP
# 937         937.0              FP           NaN        NaN    FP
# 1020       1020.0              FP           NaN        NaN    FP
# 1081          NaN        B-ID_NUM         ras21       22.0    FN
# 1082          NaN  I-NAME_STUDENT        Mpanza      596.0    FN
#
#                label  row_id
# 5     B-NAME_STUDENT     5.0
# 13    B-NAME_STUDENT    13.0
# 20    B-NAME_STUDENT    20.0
# 25    B-NAME_STUDENT    25.0
# 29    B-NAME_STUDENT    29.0
# 203   B-NAME_STUDENT   203.0
# 207   B-NAME_STUDENT   207.0
# 289   B-NAME_STUDENT   289.0
# 294   B-NAME_STUDENT   294.0
# 295   B-NAME_STUDENT   295.0
# 298   B-NAME_STUDENT   298.0
# 322   B-NAME_STUDENT   322.0
# 358   B-NAME_STUDENT   358.0
# 365   B-NAME_STUDENT   365.0
# 371   B-NAME_STUDENT   371.0
# 372   B-NAME_STUDENT   372.0
# 374   B-NAME_STUDENT   374.0
# 378   B-NAME_STUDENT   378.0
# 381   B-NAME_STUDENT   381.0
# 383   B-NAME_STUDENT   383.0
# 384   B-NAME_STUDENT   384.0
# 431   B-NAME_STUDENT   431.0
# 477   B-NAME_STUDENT   477.0
# 547   B-NAME_STUDENT   547.0
# 602   B-NAME_STUDENT   602.0
# 610   B-NAME_STUDENT   610.0
# 717   B-NAME_STUDENT   717.0
# 718   B-NAME_STUDENT   718.0
# 720   B-NAME_STUDENT   720.0
# 746   B-NAME_STUDENT   746.0
# 753   B-NAME_STUDENT   753.0
# 754   B-NAME_STUDENT   754.0
# 829   B-NAME_STUDENT   829.0
# 937   B-NAME_STUDENT   937.0
# 1020  B-NAME_STUDENT  1020.0
# 1081             NaN     NaN
# 1082             NaN     NaN

# %%
df[df["document"]==21345]
# Out:
#     Unnamed: 0  token      label_pred  document token_text_pred  row_id_pred  \
# 73          73    131  B-NAME_STUDENT     21345            Ravi         73.0
# 74          74   1289  B-NAME_STUDENT     21345            Ravi         74.0
#
#    label_gt token_text_gt  row_id_gt  cm
# 73       FP           NaN        NaN  FP
# 74       FP           NaN        NaN  FP

# %%
# df.loc[df["cm"]=="FP", "cm"] = ""
# df.loc[df["cm"]=="FN", "cm"] = "TP"
# df.loc[df["cm"]=="FNFP", "cm"] = "TP"

df.loc[(df["label_pred"]=="I-USERNAME") & (df["cm"]=="FP"), "cm"] = ""


FP = (df["cm"].isin({"FP", "FNFP"})).sum()
FN = (df["cm"].isin({"FN", "FNFP"})).sum()
TP = (df["cm"] == "TP").sum()   
beta = 5
s_micro = (1 + (beta**2)) * TP / (((1 + (beta**2)) * TP) + ((beta**2) * FN) + FP)

print(s_micro)
# Out:
# 0.8783783783783784

# %%
import json

data = json.load(open("/drive2/kaggle/pii-dd/data/train.json"))

# %%
d = [d for d in data if d["document"]==15045][0]
# [(x,y) for x,y in zip(d["labels"], d["tokens"]) if x!="O"]
print(d["full_text"])
# Out:
# Challenge and selection:
#
# I heard a lot about storytelling and I see all the users solve their problems with satisfaction. So I use it  recently to solve a problem in my work. I am working in a medium big company that are designing  different small SW. One day we think about a project for creating an app for an online supermarket. But  the problem was that there are a lot of application similar to the one that we wanted to create, so the  probability that we win in the market was so low. In order to consider all the point of view for creating a  winning app, I suggested to our team to use design thing storytelling tool, but I see my manger is not that  agree with my idea. So I take the responsibility and say him that I will come with a proposal to you and if  you agree we continue with my proposal. Because I was sure that story telling tool can help my manger  and all of us to see our users and app journey and as it is explaining stories, all the persons can see  themselves as the story persona and find all small critical point of app creation
#
# Application:
#
# To create personas I consider Sara. Sara is 34 years old, a busy working mom with a 2 years old son. She  works full time and has no time for shopping. She does most of her shopping online. She enjoys cooking  and likes the healthy eating style. Since she is busy working mom, a suggested shopping list would be  handy for her, the shopping list would be based on her shopping history. Sara has a family and most  families have a monthly budget, it would be useful for her to know how much money she spends on food,  household products, baby products and so on each month. She loves cooking, recipes would be a great  addition to the app, especially something like 30 mins meals and healthy family dinner. Since Sara’s life is  busy, it would help her if the app accepts monthly invoice so she can pay for her food, once a month. Till  here we were made our personas.   Then I start to create a journey of how users experience when using product and a conflict is a challenge  users face and they hope that your product is the solution. Sara first knew about the online supermarket  app on TV after a long day at work, she is tired and just noticed that she had nothing in the fridge for  dinner. She ordered takeaway and while she was waiting for her food, she downloaded the app. So we  create a journey for her when she tries the app:  1. Before she started using the app, there was a brief questionnaire to help her set up her profile. The  questionnaire includes simple questions like the number of family members, cooking style and so on.  2. After that she could start doing her online shopping. There’s a tab with suggested products and another  tab with suggested recipes. She could even put the ingredients in her shopping cart.  3. For frequently used products, like diapers, she was offered an option to subscribe so the online  supermarket delivers them every month — she wouldn’t have to worry about running out of them.  4. When she checked out, she was offered a choice to pay with her credit card or a monthly invoice.  After checking out — her takeaway arrived, perfect timing!  When I finished my story I go to my team and I explained everything. As they could imagin all the steps of  user and product journey, so they convince to go on with creating the app and using storytelling during  product creation
#
# Insight and approach:
#
# I see lots of benefits for a business— it enhances engagement, improves user experience, makes the users  become brand advocates. When it comes to design — it helps you speak to your users and create  something that makes your users’ life easier and delightful. The true beauty of a great design is not on the  outside, it lies within the solution that your product provides. The thing that maybe I change next time  when I use storytelling is that I create more than one persona, in order to be sure I consider all the things.

# %%
ord(d["full_text"][1624:1625])
# Out:
# 65533

# %%
pl = pipeline("ner", model="/drive2/kaggle/pii-dd/training/basic/dv3b-seq384-stride64-data-v2/checkpoint-2280", device=0)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
out = pl(d["full_text"])

# %%
pl("""1 Leonardo Torres\n\nReflection – Learning Launch\n\nChallenge\n\nIn this reflection about learning launch and experimentation, I would like to tell an  incident when I influenced engineering to build a particular feature. In my current role,  I’m the monetization front-end designer for our free email product.\n\nTwo weeks ago, Irina, the engineering manager, gave me some bad news, "Leonardo,  I’m sorry, but we have to remove 140x500 skyscraper ad. My engineering VP told me  that the PM team wouldn’t mind."\n\nI was thinking to myself: “Are you kidding me? Wouldn’t mind? This ad was only the 3rd  most valuable ad placement on the entire site. It delivered INR 45 million in revenue  per year. Who did Irina think was paying her salary?”\n\nSelection\n\nAfter I collected my emotions, I asked Irina, “When are you planning to remove it?”  She said, “Two code sprints from now. About 6 weeks.”\n\nI told her, “Can you give me three days to pull some data? I’d like to understand the  impact of this decision.”\n\nAfter she left, I thought: what could I do? I could have a hissy fit and complain loudly.  Or I could immediately escalate to the engineering VP.\n\nWhile I was tempted to go with either or both solutions, I wouldn’t get what I want  unless I was armed with the facts. Before I figured my plan, I gave my boss Luca, a  heads-up. He wasn’t pleased with engineering’s unilateral response, but he agreed with  my plan.\n\nApplication\n\nI logged into the data warehouse and pulled revenue numbers for the last 12 months.  Next I asked to sales team to gauge customer reaction if we no longer made the product  available. Lastly, I reached out to the VP Engineering’s Chief of Staff to better  understand why we wanted to remove the ad.\n\nInsight\n\nAfter I collected the data, I set up a meeting with Irina, Luca my boss, and  Luca the VP of Engineering. The VP of Engineering reiterated his decision to  remove the skyscraper ad. He maintained what I had heard earlier: the skyscraper ads  were the reason why the email product’s engagement and market share was down.\n\nI asked him, “Why do you think the ads impact engagement?”\n\n2 Leonardo Torres\n\nHe said, “They distract the user.”\n\nI replied, “Are there times when you don’t find the ads distracting?”\n\nHe said, “Yes, when it’s relevant to the content. Let’s say I’m reading an email about  meeting with friends, and the ads suggest things new restaurants and bars.\n\nSo I summarized, “So, you don’t have a problem with ads. What you’re really concerned  about is the quality of the ads.”\n\nApproach\n\nI recommended that rather than remove the ads completely, we should revisit our ad  policy and make sure that we’re serving relevant ads. We can tighten up our ad editorial  processes so that low quality ads aren’t mindlessly approved by the system.\n\nHe was shocked when I told him that the ad placement generated $45 million in annual  revenue. And he also didn’t realize that by pulling the placement, customers would pull  advertising budget, primarily because it wasn’t worth continuing a relationship with us,  given the low ad volume and lack of attractive ad placements, relative to our  competitors.\n\nOrganisation\n\nWe minimized many of the low quality teeth whitening, weight loss ads that were  known for distracting tactics such as pop-ups, fake navigation, and blinking sections.\n\nIt required a lot more work on our editorial team and advertisers. Shortly after, we later  found that email user engagement did go up by 6.5%, and most importantly, we  preserved $45 million in revenue.\n\n""")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# [{'entity': 'B-NAME_STUDENT',
#   'score': 0.5843847,
#   'index': 494,
#   'word': '\n',
#   'start': 2117,
#   'end': 2118},
#  {'entity': 'B-NAME_STUDENT',
#   'score': 0.9958347,
#   'index': 497,
#   'word': '▁Leonardo',
#   'start': 2120,
#   'end': 2129},
#  {'entity': 'I-NAME_STUDENT',
#   'score': 0.9761973,
#   'index': 498,
#   'word': '▁Torres',
#   'start': 2129,
#   'end': 2136}]
