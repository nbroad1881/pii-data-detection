# %%
from pathlib import Path
import pandas as pd
from tqdm.auto import tqdm
from collections import Counter

directory_path = '/drive2/kaggle/pii-dd/piidd/training/basic'
directory = Path(directory_path)

# Using rglob to find all CSV files recursively
csv_files = list(directory.rglob('*.csv'))


fp_info = set()

unq_doc_token = set()

fp_docs = set()
fp_counter = Counter()

# Printing the paths of found CSV files
for csv_file in tqdm(csv_files):
    df = pd.read_csv(csv_file, engine="python")

    if "cm" in df.columns:
        FP = (df["cm"].isin({"FP", "FNFP"})).sum()
        FN = (df["cm"].isin({"FN", "FNFP"})).sum()
        TP = (df["cm"] == "TP").sum()   
        beta = 5
        s_micro = (1 + (beta**2)) * TP / (((1 + (beta**2)) * TP) + ((beta**2) * FN) + FP)

        if s_micro > 0.9:
            fp_docs.update(df.loc[df["cm"].isin({"FP", "FNFP"}), "document"].tolist())
            temp = [(w, x,y,z) for w, x,y,z in df.loc[df["cm"].isin({"FP", "FNFP"}), ["label_pred", "token", "document", "token_text_pred"]].values] 

            unq_doc_token.update([(y, z) for (w, x,y,z) in temp])
            fp_counter.update(set([(y, z) for (w, x,y,z) in temp]))
            fp_info.update(temp)
# Out:
#   0%|          | 0/811 [00:00<?, ?it/s]

# %%
fn_info = set()

unq_doc_token = set()

fn_docs = set()
fn_counter = Counter()

# Printing the paths of found CSV files
for csv_file in tqdm(csv_files):
    df = pd.read_csv(csv_file, engine="python")

    if "cm" in df.columns:
        FP = (df["cm"].isin({"FP", "FNFP"})).sum()
        FN = (df["cm"].isin({"FN", "FNFP"})).sum()
        TP = (df["cm"] == "TP").sum()   
        beta = 5
        s_micro = (1 + (beta**2)) * TP / (((1 + (beta**2)) * TP) + ((beta**2) * FN) + FP)

        if s_micro > 0.9:
            fn_docs.update(df.loc[df["cm"].isin({"FN"}), "document"].tolist())
            temp = [(w, x,y,z) for w, x,y,z in df.loc[df["cm"].isin({"FN"}), ["label_gt", "token", "document", "token_text_gt"]].values] 

            unq_doc_token.update([(y, z) for (w, x,y,z) in temp])
            fn_counter.update(set([(y, z) for (w, x,y,z) in temp]))
            fn_info.update(temp)
# Out:
#   0%|          | 0/811 [00:00<?, ?it/s]

# %%
len(fp_docs), len(fn_docs)
# Out:
# (905, 294)

# %%
fp_counter
# Out:
# Counter({(10376, 'Gamal'): 113,
#          (10376, 'Simona'): 110,
#          (11535, '\u200b'): 107,
#          (12565, '\u200b'): 102,
#          (3915, '\u200b'): 102,
#          (11208, 'Glen'): 100,
#          (4600, 'Yomna'): 100,
#          (11208, 'Styles'): 98,
#          (4600, 'Isabel'): 98,
#          (3427, 'Katia'): 97,
#          (3427, 'Rania'): 97,
#          (2915, 'Carolina'): 96,
#          (8302, 'Coyle'): 96,
#          (4717, '221910309005'): 94,
#          (4717, '221910309006'): 94,
#          (11376, 'Javier'): 94,
#          (4278, '\u200b'): 93,
#          (6611, '\u200b'): 93,
#          (9854, 'vpi@mn.nl'): 93,
#          (10693, 'Jeremy'): 92,
#          (5001, 'Rya'): 88,
#          (10220, 'Maria'): 87,
#          (7993, 'Ortega'): 87,
#          (19280, '30407059'): 87,
#          (8344, 'Janet'): 86,
#          (8344, 'Galletti'): 86,
#          (10251, '\u200b'): 86,
#          (8302, 'Sibanda'): 86,
#          (12803, 'Nickie'): 86,
#          (12120, 'Madrid'): 85,
#          (3894, '\u200b'): 85,
#          (2915, 'Gomez'): 85,
#          (10632, 'Rahim'): 85,
#          (12106, '�'): 85,
#          (9629, 'Amin'): 84,
#          (11806, '\u200b'): 84,
#          (10693, 'Borg'): 84,
#          (3709, 'Katia'): 82,
#          (9629, 'Maria'): 81,
#          (1210, 'Matheus'): 79,
#          (3709, '-'): 79,
#          (104, 'Dr'): 78,
#          (12803, 'Ahmed'): 78,
#          (9421, 'Libby'): 78,
#          (3709, '2182'): 78,
#          (11698, 'Rodriguez'): 77,
#          (9585, 'Michelle'): 77,
#          (3709, '5386'): 77,
#          (11698, 'Sally'): 76,
#          (7262, 'Poland'): 76,
#          (3709, 'Johnson'): 76,
#          (13047, '\u200b'): 75,
#          (12483, 'Weyhacy_7000693584'): 75,
#          (4090, 'Aakash'): 75,
#          (7197, 'Alice'): 75,
#          (8108, 'Vikas'): 74,
#          (11392, 'Barbosa'): 73,
#          (11806, '\u200bMatshepo\u200b'): 72,
#          (12215, 'Toni'): 71,
#          (5662, 'OUSSOU'): 71,
#          (9493, 'NITHIN'): 71,
#          (3709, '2321'): 71,
#          (3709, '1'): 71,
#          (10561, 'https://www.youtube.com/watch?v=n90uKuFh9Go'): 70,
#          (6622, 'Chavez'): 70,
#          (9493, 'SUNITH'): 70,
#          (12512, 'HOWRAH-711103'): 69,
#          (3709, '9637'): 69,
#          (1798, 'Williams'): 68,
#          (6622, 'Carolina'): 68,
#          (11392, 'Ashley'): 67,
#          (8962, 'Kiran'): 66,
#          (11806, 'Matshepo\u200b'): 66,
#          (4698, 'V'): 66,
#          (1798, 'Marcos'): 66,
#          (3540, 'Fabian'): 66,
#          (8842, 'Ingram'): 65,
#          (4717, ':'): 65,
#          (8751, 'B8'): 65,
#          (10220, 'Paolina'): 64,
#          (6537, '9043'): 63,
#          (6537, '9027'): 63,
#          (8751, 'CSE'): 63,
#          (1290, 'Bello'): 63,
#          (8842, 'Elisa'): 62,
#          (6393, 'https://www.youtube.com/watch?v=Nj-hdQMa3uA'): 62,
#          (8751, '-'): 61,
#          (330, 'Marias'): 61,
#          (1290, 'David'): 61,
#          (1798, 'Maria'): 61,
#          (3540, 'Jones'): 61,
#          (9421, 'Bingham'): 60,
#          (13311, 'Nancy'): 59,
#          (6718, 'Rob'): 58,
#          (13017, 'Juana'): 57,
#          (13311, 'Gonsalez'): 57,
#          (15717, '-'): 57,
#          (9674, 'Alicia'): 56,
#          (6537, '9023'): 56,
#          (8302, 'Pamela'): 55,
#          (8894, 'Mari'): 55,
#          (7745, 'Daniel'): 55,
#          (3709, 'Ari'): 55,
#          (11849, 'Arman'): 55,
#          (8344, 'Marcel'): 54,
#          (9818, 'Giovanna'): 53,
#          (330, 'Gamesa'): 53,
#          (3202, 'nYZqnhEXw'): 52,
#          (15717, 'UVA'): 52,
#          (11745, 'Pedro'): 51,
#          (12512, 'Jordi'): 51,
#          (8894, 'Ahmed'): 50,
#          (6849, '034626995785'): 50,
#          (12512, 'SHIBPUR'): 50,
#          (6694, 'https://www.youtube.com/watch?v=al3-Kl4BDUQ'): 49,
#          (2722, 'https://www.solfiten.com/'): 49,
#          (6600, 'Jack'): 49,
#          (9493, 'Radha'): 48,
#          (11376, 'Fabio'): 48,
#          (2769, 'Daniela'): 46,
#          (12215, 'David'): 45,
#          (379, 'linkedIn'): 45,
#          (10205, 'Migual'): 45,
#          (11900, 'John'): 45,
#          (9854, 'Netherlands'): 45,
#          (3709, 'Arik'): 45,
#          (9818, 'Salama'): 44,
#          (9674, 'Durand'): 44,
#          (15717, 'IV-8322'): 44,
#          (11900, 'Benjamin'): 44,
#          (9674, 'Diane'): 43,
#          (6600, 'Andraka'): 43,
#          (6694, 'https://www.youtube.com/watch?v=5Zuq92PUr5E'): 41,
#          (12512, ','): 41,
#          (3709, 'Eko'): 41,
#          (4769, 'Gracias'): 40,
#          (11116, 'Polly'): 40,
#          (13198, '215'): 40,
#          (5561, 'Sue'): 39,
#          (2769, 'Sangineto'): 39,
#          (5433, 'UdelaR'): 39,
#          (11793, 'hallenge'): 38,
#          (5561, 'Abdeldayem'): 38,
#          (6459, 'https://www.rapidtables.com/tools/notepad.html'): 38,
#          (13311, 'Luis'): 38,
#          (6282, 'Juan'): 38,
#          (6694, 'https://www.ideo.com/about/'): 38,
#          (10205, 'Oman'): 38,
#          (10220, 'María'): 37,
#          (13144, 'gdelossantos'): 37,
#          (10672, 'Ari'): 36,
#          (3709, 'Cucun'): 36,
#          (8344, 'Mia'): 35,
#          (3579, 'CT'): 35,
#          (6537, 'CS4'): 35,
#          (4214, 'Khurais'): 35,
#          (3709, 'Kurniawati'): 35,
#          (4185, 'Marie'): 34,
#          (8344, 'Tina'): 33,
#          (19042, '\u200b'): 33,
#          (9854, 'The'): 33,
#          (4381, 'ph'): 32,
#          (13343, 'Lustri'): 32,
#          (13343, 'Mellissa'): 32,
#          (3579, 'Newtown'): 32,
#          (4381, 'http://au.youtube.com/results?search_query=tony+buzan'): 31,
#          (11116, 'Enrique'): 31,
#          (11900, '723847538279'): 31,
#          (12512, 'GARDEN'): 31,
#          (4214, 'Mega'): 31,
#          (9760, 'Bk'): 30,
#          (18306, 'Lili'): 30,
#          (5653, '35615904922'): 30,
#          (7713, 'https://www.youtube.com/watch?v=NuacmGHLDqw'): 30,
#          (4842, 'https://comichouse.nl/category/live-cartooning/'): 30,
#          (18601, '\u200b'): 29,
#          (10448, 'Kanali'): 29,
#          (5628, 'Tapez'): 29,
#          (6591, '276795361801'): 29,
#          (6537, '955487471144'): 28,
#          (21578, 'Schmader'): 28,
#          (21578, 'Brett'): 28,
#          (7137, 'FQAAAAAdAAAAABAD'): 28,
#          (13198, 'OTP'): 28,
#          (16684, 'https://youtu.be/LyaUS2PNiVQ'): 28,
#          (3709, 'Yuniarno'): 28,
#          (3709, 'Kusumaningsih'): 28,
#          (11228, 'Doña'): 27,
#          (11228, 'María'): 27,
#          (9760, 'Md'): 27,
#          (12255, 'Millette'): 27,
#          (18008, 'Vicente'): 27,
#          (7137, 'AOvVaw18HOrC-'): 27,
#          (22188, '�'): 27,
#          (13249, 'Sally'): 27,
#          (22021, 'Knipschild'): 27,
#          (22021, 'Chad'): 27,
#          (3709, '0/17'): 27,
#          (11654, '10JUL20'): 26,
#          (123, 'Sathyabama'): 26,
#          (12397, 'Sobuj'): 26,
#          (22109, 'Hamzah'): 26,
#          (22109, 'Halawani'): 26,
#          (2722, 'Hector'): 26,
#          (12184, 'Ajay'): 26,
#          (11588, '\u200b'): 26,
#          (18536, 'Tamakani'): 26,
#          (8751, 'Branch'): 26,
#          (20159, '�'): 25,
#          (5249, 'Mrs.'): 25,
#          (9657, 'Schneider'): 25,
#          (13862, '\u200b'): 25,
#          (5001, '�'): 25,
#          (3709, 'Angkoso'): 25,
#          (3709, 'Mochammad'): 25,
#          (11116, 'Daniel'): 24,
#          (11047, 'https://youtu.be/Am8EE3SBnAo'): 24,
#          (9657, 'Daniel'): 24,
#          (9289, 'Salvador'): 24,
#          (1290, 'Mr'): 24,
#          (12823, '\u200b'): 24,
#          (21867, '�'): 24,
#          (15524, 'Doña'): 24,
#          (15524, 'María'): 24,
#          (3709, 'Mulyanto'): 24,
#          (9760, '943995368223'): 23,
#          (9098, 'Omar'): 23,
#          (9098, 'Vulpinari'): 23,
#          (14701, '\u200b'): 23,
#          (1447, 'https://miro.com'): 23,
#          (12512, 'BOTANICAL'): 23,
#          (671, 'Absträct'): 23,
#          (18776, '�'): 23,
#          (3709, 'Very'): 23,
#          (11261, 'Belén'): 23,
#          (6459, 'ks31k'): 23,
#          (2694, 'Joshua'): 23,
#          (7676, 'Sanella'): 22,
#          (21564, 'Harrington'): 22,
#          (21564, 'Chesdin'): 22,
#          (11644, 'Freitag'): 22,
#          (19104, 'Anthony'): 22,
#          (19104, 'Johnson'): 22,
#          (5001, 'I'): 22,
#          (21165, 'Rik'): 22,
#          (9629, 'Valerie'): 22,
#          (10908, 'Rosangela'): 22,
#          (10908, 'Watkins'): 22,
#          (16684, 'John'): 22,
#          (18969, '\u200b'): 21,
#          (20405, 'Cousera'): 21,
#          (11262, 'Anna'): 21,
#          (19143, '�'): 21,
#          (6459, 'VanDeCarr'): 21,
#          (2694, 'Edwards'): 21,
#          (19936, 'Prescott'): 21,
#          (609, 'Kasyap'): 20,
#          (21580, 'Christopher\u200b'): 20,
#          (9653, 'Man'): 20,
#          (21580, '\u200bThorborg'): 20,
#          (18008, 'Vincent'): 20,
#          (22656, '\u200b'): 20,
#          (8642, 'Aakash'): 20,
#          (5344, 'Visvesvaraya'): 20,
#          (8894, 'UVA'): 20,
#          (6282, 'Chavez'): 20,
#          (4462, 'fdixon'): 20,
#          (7786, ')'): 20,
#          (19936, 'Cachet'): 20,
#          (15032, 'Valeria'): 20,
#          (22206, 'Madelon'): 19,
#          (17568, 'Joana'): 19,
#          (5590, 'Lear'): 19,
#          (14313, '\u200b'): 19,
#          (1814, 'Mango'): 19,
#          (6459, 'Paul'): 19,
#          (2722, 'Jaramillo'): 19,
#          (21541, 'Ariana'): 19,
#          (21541, 'Tsoutsas'): 19,
#          (11261, 'Belen'): 19,
#          (22023, 'Kolusu'): 19,
#          (22023, 'Vinay'): 19,
#          (11896, 'Simón'): 19,
#          (3709, 'Farhan'): 19,
#          (15032, 'Garcia'): 19,
#          (14428, '\u200b'): 18,
#          (4214, 'Diego'): 18,
#          (19276, 'Garcia'): 18,
#          (5590, 'Ning'): 18,
#          (12379, 'Orange'): 18,
#          (18306, 'Hola'): 18,
#          (1814, 'Rustic'): 18,
#          (3579, ','): 18,
#          (12564, 'Silvia'): 18,
#          (6853, 'George'): 18,
#          (3709, 'Hariadi'): 18,
#          (19469, 'Bayo'): 18,
#          (12981, '�'): 18,
#          (12429, 'Shiv'): 18,
#          (6537, '779875708882'): 17,
#          (11116, 'http://lospaleteros.com/'): 17,
#          (12184, '014674070485'): 17,
#          (11900, '836172426340'): 17,
#          (19143, 'Sam'): 17,
#          (6537, '800306846075'): 17,
#          (6450, '51&56'): 17,
#          (16467, 'Michellin'): 17,
#          (6946, 'Estela'): 17,
#          (3709, 'Shreya'): 17,
#          (17905, 'Rameshwar'): 16,
#          (14916, 'Natália'): 16,
#          (19280, 'Z.S.'): 16,
#          (19565, 'Danielle'): 16,
#          (4381, 'North'): 16,
#          (8575, 'Kirill'): 16,
#          (8894, 'DARDEN'): 16,
#          (13047, '\u200bSarah\u200b'): 16,
#          (17336, 'Dele'): 16,
#          (22088, 'Reyes'): 16,
#          (22088, 'María'): 16,
#          (22088, 'José'): 16,
#          (13123, '/'): 16,
#          (13123, 'watch?v=5nTuScU70As'): 16,
#          (10890, '\u200b'): 16,
#          (6459, 'https://www.viddsee.com/video/bak-gia-'): 16,
#          (6459, '/'): 16,
#          (15720, '2000414'): 16,
#          (10151, 'Ali'): 16,
#          (18087, '�'): 15,
#          (9648, 'Manj'): 15,
#          (19071, 'Namokar'): 15,
#          (4214, 'Becerra'): 15,
#          (3987, 'Coursera_Design'): 15,
#          (11900, '871483046449'): 15,
#          (4381, 'Terrace'): 15,
#          (10559, 'Doering'): 15,
#          (10559, 'Mike'): 15,
#          (13649, 'Santosh'): 15,
#          (15686, 'Anita'): 15,
#          (14267, 'Robert'): 15,
#          (16551, 'Siddharth'): 15,
#          (11750, 'Robert'): 15,
#          (10802, 'Asad'): 15,
#          (4574, 'Annie'): 15,
#          (6282, 'Mohamed'): 15,
#          (14593, 'https://youtu.be/_vS_b7cJn2A'): 15,
#          (6946, 'Perez'): 15,
#          (20850, 'https://youtu.be/fPAnKZjejmU'): 15,
#          (8936, 'Kumar'): 15,
#          (13123, '\u200bhttps://www.youtube.com'): 15,
#          (13144, '/'): 15,
#          (9117, 'https://otter.ai'): 14,
#          (14664, 'https://www.youtube.com/watch?v=V5BQnifIwA0'): 14,
#          (9760, 'Sama'): 14,
#          (12510, '�'): 14,
#          (15226, 'pvc'): 14,
#          (19565, 'Schlosser'): 14,
#          (4214, 'Felipe'): 14,
#          (5902, 'Karen'): 14,
#          (20539, 'Benita'): 14,
#          (11442, 'Milano'): 14,
#          (12154, '10.1080/00405840802153916'): 14,
#          (13336, 'Thomas'): 14,
#          (18270, '\u200b'): 14,
#          (11856, 'Geoff'): 14,
#          (16551, 'Shiddharth'): 14,
#          (15652, '�'): 14,
#          (6282, 'Antonio'): 14,
#          (14642, 'Gutierrez'): 14,
#          (5855, 'Liiv'): 14,
#          (5896, 'Donya'): 14,
#          (17258, 'https://youtu.be/xCyjFipytRE'): 14,
#          (609, 'SSRK'): 14,
#          (11442, '1861'): 14,
#          (15717, '-3-'): 14,
#          (21538, 'Brulliea'): 13,
#          (21538, 'Alex'): 13,
#          (21715, 'https://www.youtube.com/watch?v=I0qsOs1Y4Do'): 13,
#          (4381, 'Central'): 13,
#          (7745, 'Savitribai'): 13,
#          (3579, 'USA'): 13,
#          (16741, 'E’manuel'): 13,
#          (18454, 'Jimmy'): 13,
#          (12565, 'Adebayo'): 13,
#          (8714, '762035863358'): 13,
#          (11387, 'UVA'): 13,
#          (11387, 'BP-0550'): 13,
#          (3402, 'www.theatfc.org'): 13,
#          (19143, 'Yen'): 13,
#          (8936, 'Vicky'): 13,
#          (3709, 'Srinivasan'): 13,
#          (18839, '�'): 13,
#          (12267, 'De'): 13,
#          (7203, 'Group'): 12,
#          (9648, 'manj'): 12,
#          (12184, '369615882777'): 12,
#          (17063, 'Ali'): 12,
#          (21527, 'Ostrowski'): 12,
#          (21527, 'Tomasz'): 12,
#          (20539, 'Yap'): 12,
#          (18500, 'Raisa'): 12,
#          (21233, 'Crabby'): 12,
#          (21233, 'Johns'): 12,
#          (4777, '('): 12,
#          (9289, 'Don'): 12,
#          (21142, 'Adam'): 12,
#          (7427, 'Bhubaneswar'): 12,
#          (8575, 'Yankov'): 12,
#          (4553, 'Mihaly'): 12,
#          (609, '054176622314'): 12,
#          (4842, 'https://mural.com'): 12,
#          (11387, '-'): 12,
#          (21711, 'Pierre'): 12,
#          (15824, 'http://youtu.be/2PBeRbWE79w'): 12,
#          (14446, 'https://www.youtube.com/watch?v=9URSbTOE4YI'): 12,
#          (10325, 'https://www.youtube.com/watch?v=fiyaYII7ROA'): 12,
#          (16684, 'David'): 12,
#          (3709, 'Ankit'): 12,
#          (12184, 'Cs-1'): 12,
#          (11901, 'Jeilan'): 12,
#          (10327, '\u200b'): 12,
#          (8935, 'Keells'): 12,
#          (8935, 'John'): 12,
#          (19530, 'Susan'): 12,
#          (7680, '\xad'): 12,
#          (17415, 'Tommy'): 12,
#          (19289, 'Sam'): 11,
#          (4717, '186941941714'): 11,
#          (6257, 'here'): 11,
#          (9905, 'Javier'): 11,
#          (9657, 'Q'): 11,
#          (11841, 'Andrés'): 11,
#          (5628, 'ici'): 11,
#          (9760, '208798413907'): 11,
#          (6282, 'Cinxel'): 11,
#          (8758, 'Pepe'): 11,
#          (8758, 'Anthony'): 11,
#          (17832, 'https://medium.com/unilaproex'): 11,
#          (8108, 'raj'): 11,
#          (20921, 'Fernandez'): 11,
#          (20921, 'Manav'): 11,
#          (11442, ')'): 11,
#          (9203, 'Vanessa'): 11,
#          (13603, 'Romero'): 11,
#          (13603, 'Manuel'): 11,
#          (22106, 'LAURA'): 11,
#          (14027, 'https://www.youtube.com/watch?v=usX9vkxK5xA'): 11,
#          (15045, 'Sara'): 11,
#          (14446, 'https://www.youtube.com/watch?v=PqS-bWQ3YA8'): 11,
#          (21345, 'Ravi'): 11,
#          (11901, 'Devanesan'): 11,
#          (3709, 'Bhairavi'): 11,
#          (3709, 'Neel'): 11,
#          (7786, 'Manuela'): 11,
#          (3709, 'Vinaya'): 11,
#          (11793, 'Experi'): 11,
#          (11954, '2'): 11,
#          (11116, 'Phillips'): 10,
#          (11116, 'Edgar'): 10,
#          (308, 'Hunt'): 10,
#          (308, 'Garda'): 10,
#          (17063, 'Sarah'): 10,
#          (10147, 'https://www.youtube.com/watch?v=5nTuScU70As'): 10,
#          (6007, 'Cyilinder'): 10,
#          (9783, '\u200b'): 10,
#          (20539, 'Catalino'): 10,
#          (4214, 'Rajagiri'): 10,
#          (10324, 'Durand'): 10,
#          (20389, 'VISUAioLSZAoISon'): 10,
#          (13631, 'Sam'): 10,
#          (10196, 'Kumar'): 10,
#          (12446, 'Steve'): 10,
#          (21872, 'https://www.youtube.com/watch?v=FZSpUfsoezY'): 10,
#          (15400, 'Mario'): 10,
#          (7909, 'Bogotá'): 10,
#          (16485, 'Hussain'): 10,
#          (10782, 'Jennifer'): 10,
#          (2651, 'Bono'): 10,
#          (10802, 'West'): 10,
#          (2769, 'Soria'): 10,
#          (11116, 'Artiñano'): 10,
#          (14043, 'Kike'): 10,
#          (4276, 'Pierre'): 10,
#          (9313, 'Max'): 10,
#          (13649, 'Sumitra'): 10,
#          (14446, 'https://www.youtube.com/watch?v=oR__WIK_yqk'): 10,
#          (14446, 'https://www.youtube.com/watch?v=wouXuqJiCro'): 10,
#          (13144, '/Users'): 10,
#          (10890, 'Angela'): 10,
#          (20, 'George'): 10,
#          (6459, 'eyeglasses'): 10,
#          (8302, 'Joyce'): 10,
#          (4381, 'www.adelaide.edu.au/writingcentre/'): 10,
#          (10483, 'Gregoire'): 10,
#          (11927, 'Harina'): 10,
#          (4878, 'Jose'): 10,
#          (11954, '1'): 10,
#          (14333, 'Isiah'): 9,
#          (18804, 'Javier'): 9,
#          (10324, 'Diane'): 9,
#          (10324, 'Alicia'): 9,
#          (11373, 'Coursera'): 9,
#          (14267, 'Beckler'): 9,
#          (7668, 'Amira'): 9,
#          (8612, 'Sofia'): 9,
#          (8674, 'Dr.'): 9,
#          (13653, 'https://www.youtube.com/watch?v=SONOxZkG5xk'): 9,
#          (13653, 'https://www.youtube.com/watch?v=twbHCOQkspY'): 9,
#          (19567, 'Jah'): 9,
#          (9493, 'Aerospace'): 9,
#          (4553, 'Csikszentmihalyi'): 9,
#          (7858, 'https://coggle.it/'): 9,
#          (7137, 'vfe&ved=0CAIQjRxqFwoTCMDi_tOdhu0C'): 9,
#          (7745, 'Phule'): 9,
#          (11750, 'Rob'): 9,
#          (11698, 'Cuenca'): 9,
#          (16485, 'Dawood'): 9,
#          (12055, ':'): 9,
#          (11437, 'www.gv.com/sprint'): 9,
#          (10802, 'Andrea'): 9,
#          (4971, '943063077874'): 9,
#          (8733, 'Miro'): 9,
#          (21486, 'Schlumberger'): 9,
#          (6282, 'Jairo'): 9,
#          (22106, 'SOFÍA'): 9,
#          (123, 'https://cyberleninka.ru/article/n/14398333'): 9,
#          (21345, 'Arvind'): 9,
#          (13299, 'Brittany'): 9,
#          (16947, 'Sathyabama'): 9,
#          (10873, 'https://www.youtube.com/watch?v=yWEqiyia-Qs'): 9,
#          (20531, 'vijay'): 9,
#          (3709, 'Yashwant'): 9,
#          (15268, 'Antonio'): 9,
#          (7786, 'Beltran'): 9,
#          (14728, 'Joy'): 9,
#          (18981, 'Preksha'): 9,
#          (9799, 'John'): 9,
#          (11849, 'Antonio'): 9,
#          (11849, 'Finca'): 9,
#          (4709, 'Goeff'): 9,
#          (1290, 'Senior'): 9,
#          (7993, '2'): 9,
#          (10890, 'Meyer'): 9,
#          (14135, 'AR'): 9,
#          (15319, 'Peter'): 9,
#          (17578, 'Anna'): 8,
#          (13950, 'Ahmed'): 8,
#          (6257, 'see'): 8,
#          (22206, 'René'): 8,
#          (7680, 'Crystal'): 8,
#          (8192, 'Papers'): 8,
#          (13193, 'John'): 8,
#          (20503, 'Challende'): 8,
#          (11900, '534516353860'): 8,
#          (7909, 'Colombia'): 8,
#          (20539, 'Vinston'): 8,
#          (11108, 'coursera'): 8,
#          (9854, '('): 8,
#          (19493, 'Mike'): 8,
#          (19493, 'Atkinson'): 8,
#          (19665, 'Skete'): 8,
#          (21940, 'Tim'): 8,
#          (21940, 'Chi'): 8,
#          (7932, "'"): 8,
#          (9493, '2'): 8,
#          (11354, 'Benjamin'): 8,
#          (11197, 'Alexei'): 8,
#          (11197, 'Mikhail'): 8,
#          (9241, 'Ilaria'): 8,
#          (14295, 'Trusty'): 8,
#          (10802, 'Gibbs'): 8,
#          (9405, 'Renter'): 8,
#          (5855, 'Mate'): 8,
#          (11566, 'Giuseppe'): 8,
#          (6296, 'Murillo'): 8,
#          (6296, 'Mary'): 8,
#          (19872, 'Loureiro'): 8,
#          (19853, 'https://www.youtube.com/watch?v=r1A3yThBaiQ&t=11s'): 8,
#          (20531, 'vinay'): 8,
#          (13299, 'Jackson'): 8,
#          (16151, 'https://www.youtube.com/watch?v=iXmXczQFQLQ'): 8,
#          (13017, 'N.L.'): 8,
#          (15686, 'Victor'): 8,
#          (3709, 'Kulkarni'): 8,
#          (3709, 'Kushal'): 8,
#          (3709, 'Kamani'): 8,
#          (5319, 'Kenia'): 8,
#          (18514, 'https://www.youtube.com/watch?v=2Ev1ciZ5e1g&t=1s'): 8,
#          (15753, 'Liberata'): 8,
#          (11975, 'Page'): 8,
#          (13144, 'Library'): 8,
#          (3709, 'Sailee'): 8,
#          (3709, 'Ashraful'): 8,
#          (3709, 'Kriti'): 8,
#          (3709, 'Vaishnavi'): 8,
#          (3709, 'hamid'): 8,
#          (4185, 'Florian'): 8,
#          (11498, 'Abdul'): 8,
#          (19469, 'Blessing'): 8,
#          (9961, 'Erin'): 8,
#          (10251, '/'): 8,
#          (10251, 'blog'): 8,
#          (10251, '\u200bhttps://venngage.com'): 8,
#          (11896, 'Simon'): 8,
#          (6853, 'Geoff'): 8,
#          (11498, 'Ali'): 8,
#          (5215, 'Unmesh'): 8,
#          (3911, 'Mayo'): 8,
#          (10324, 'Khairah'): 8,
#          (12657, 'Peter'): 8,
#          (12184, '264945858442'): 7,
#          (12184, '320622779078'): 7,
#          (7932, '18:19:48'): 7,
#          (9760, 'Giuseppe'): 7,
#          (22406, 'Saha'): 7,
#          (22406, 'Rita'): 7,
#          (19565, 'Silvia'): 7,
#          (9760, '347376430553'): 7,
#          (6124, 'Peru'): 7,
#          (6124, 'Lima'): 7,
#          (18500, 'Fyodorovna'): 7,
#          (18226, 'Jackson'): 7,
#          (17182, 'ALEX'): 7,
#          (8758, 'Adamu'): 7,
#          (17182, 'OSTERWALDER'): 7,
#          (10008, 'Rafael'): 7,
#          (10621, 'Matthias'): 7,
#          (14333, 'Strickland'): 7,
#          (7137, 'Dianne'): 7,
#          (11197, 'Pavel'): 7,
#          (6784, 'Darden'): 7,
#          (11714, 'Om'): 7,
#          (609, '860632713425'): 7,
#          (17815, 'Tena'): 7,
#          (21524, 'Maxell'): 7,
#          (21524, 'John'): 7,
#          (5380, 'Dhanteras'): 7,
#          (2335, 'Desing'): 7,
#          (2651, 'Edward'): 7,
#          (8302, 'Shahed'): 7,
#          (9203, 'Sanchez'): 7,
#          (22106, 'CARMONA'): 7,
#          (19841, 'Anna'): 7,
#          (16660, 'Sam'): 7,
#          (12405, 'Bob'): 7,
#          (20531, 'vikas'): 7,
#          (5380, 'Akshata'): 7,
#          (14191, 'Alvarez'): 7,
#          (14191, 'Jessica'): 7,
#          (3709, 'Pawar'): 7,
#          (8798, 'Hollauf'): 7,
#          (11498, 'Edhi'): 7,
#          (9961, 'Mayers'): 7,
#          (10483, 'Grégoire'): 7,
#          (17076, '270220'): 7,
#          (8340, 'Petrosillo'): 7,
#          (123, 'https://www.melessa.uni-'): 7,
#          (9905, 'Gonzalez'): 7,
#          (11927, 'Integral'): 7,
#          (2790, 'George'): 7,
#          (13694, 'Zanee'): 7,
#          (12977, 'Matthias'): 7,
#          (21322, 'Taryn'): 7,
#          (4669, 'Shamim'): 7,
#          (10457, 'teens'): 7,
#          (12653, 'Joey'): 6,
#          (11049,
#           'https://coursera.org/share/c353af95218bc2990ee616d6d583c91a'): 6,
#          (11841, 'Diana'): 6,
#          (11461, '301'): 6,
#          (1290, 'iphone'): 6,
#          (16424, 'Benz'): 6,
#          (16424, 'Mercedes'): 6,
#          (9957, 'Chuck'): 6,
#          (11966, 'Shoptimus'): 6,
#          (11966, 'Prime'): 6,
#          (8575, 'Sobyanin'): 6,
#          (11082, 'C.'): 6,
#          (7932, "-06'00"): 6,
#          (8621, 'Marina'): 6,
#          (10621, 'Walther'): 6,
#          (3786, 'https://miro.com'): 6,
#          (19567, 'Page'): 6,
#          (19663, 'Dilmodas'): 6,
#          (7680, 'Luna'): 6,
#          (7137, 'Ty'): 6,
#          (14267, 'Alan'): 6,
#          (17815, 'Ehab'): 6,
#          (4094, 'MDI-191'): 6,
#          (15461, 'bh'): 6,
#          (17534, 'Yin'): 6,
#          (15461, 'hjghfbj'): 6,
#          (379, 'DC'): 6,
#          (20921, 'Suresh'): 6,
#          (2769, 'Ruben'): 6,
#          (659, 'JLT'): 6,
#          (21486, 'Private'): 6,
#          (17836, 'Lucy'): 6,
#          (5219, 'Zoozo'): 6,
#          (9493, '522233062166'): 6,
#          (18062, 'Maria'): 6,
#          (14436, 'Espejo'): 6,
#          (8848, '/'): 6,
#          (8848, 'instagram'): 6,
#          (8848, 'linkedin'): 6,
#          (12599, 'Victoria'): 6,
#          (8831, 'Jane'): 6,
#          (5319, 'Ñarñaku'): 6,
#          (15575, 'Amit'): 6,
#          (10873, 'https://www.youtube.com/watch?v=Z4fO_NAFQ3c'): 6,
#          (3709, 'Ramesh'): 6,
#          (5319, 'Sony'): 6,
#          (11878, 'LCSW'): 6,
#          (3709, 'Anagaha'): 6,
#          (123, 'Gerashchenko'): 6,
#          (4185, 'Singer'): 6,
#          (11679, 'https://cdc.gov/coronavirus'): 6,
#          (4381, 'Hub'): 6,
#          (3709, 'Morde'): 6,
#          (3709, 'Rutuja'): 6,
#          (5215, 'Akshay'): 6,
#          (13017, 'Monterrey'): 6,
#          (18514, 'https://www.youtube.com/watch?v=HZ4gVlT93R4&t=1s'): 6,
#          (10331, 'Georgia'): 6,
#          (8798, 'Michael'): 6,
#          (16299, 'David'): 6,
#          (14277, 'Ana'): 6,
#          (609, '530670102508'): 6,
#          (8831, 'Brandon'): 6,
#          (1290, 'senior'): 6,
#          (21322, 'Anna'): 6,
#          (12977, 'Thomas'): 6,
#          (5855, 'jeoya'): 6,
#          (12265, 'Eric'): 6,
#          (11208, 'Cleveland'): 6,
#          (12657, 'John'): 6,
#          (10457, 'smart'): 6,
#          (10331, 'Bethany'): 6,
#          (14040, 'PP'): 6,
#          (3911, 'John'): 5,
#          (8892, 'Tesla'): 5,
#          (9358, '8)35'): 5,
#          (11841, 'Vallejo'): 5,
#          (13184, 'Madeleine'): 5,
#          (6007, 'cyilinder'): 5,
#          (11714, 'Ser'): 5,
#          (13355, 'GRACE'): 5,
#          (9854, ')'): 5,
#          (18500, 'Fedorovna'): 5,
#          (18226, 'Tina'): 5,
#          (10008, 'Pimenta'): 5,
#          (9553, 'Espèce'): 5,
#          (9553, 'Gage'): 5,
#          (21192, 'John'): 5,
#          (9543, 'QuesJons'): 5,
#          (6784, 'see'): 5,
#          (8960, 'Sean'): 5,
#          (8960, 'Decatur'): 5,
#          (20022, 'Frank'): 5,
#          (9493, '1'): 5,
#          (9543, 'Thulani'): 5,
#          (7137, 'vfe&ved=0CAIQjRxqFwoTCPiBraidhu0CFQAAAAAdAAAAABAJ'): 5,
#          (609, '557349702179'): 5,
#          (609, '674915248960'): 5,
#          (15461, 'Rtvnkmkkkugseahfh'): 5,
#          (11770, 'Stefania'): 5,
#          (17205, 'Aya'): 5,
#          (7, 'Avril'): 5,
#          (13008, 'George'): 5,
#          (21486, '-'): 5,
#          (9657, 'Dick'): 5,
#          (12564, 'Fado'): 5,
#          (9493, '843756944804'): 5,
#          (4971, '792389774673'): 5,
#          (19872, 'Instituto'): 5,
#          (14436, 'González'): 5,
#          (14436, '-'): 5,
#          (8848, 'fb'): 5,
#          (20539, 'Samuel'): 5,
#          (20415, 'Steve'): 5,
#          (5215, 'Kumari'): 5,
#          (659, 'Raaz'): 5,
#          (10802, 'https://www.youtube.com/watch?v=sh1-9xMZIfQ'): 5,
#          (17330, 'Alicia'): 5,
#          (18578, 'EL'): 5,
#          (3709, 'Mahadik'): 5,
#          (12243, 'Nora'): 5,
#          (9498, 'LeARning'): 5,
#          (8302, '1'): 5,
#          (7427, 'XIMB-'): 5,
#          (14191, 'Stefan'): 5,
#          (11901, 'wondershare'): 5,
#          (14191, 'Kraus'): 5,
#          (20047, 'X'): 5,
#          (12405, 'James'): 5,
#          (13144, 'Containers'): 5,
#          (3709, 'Brinda'): 5,
#          (13144, 'com.microsoft'): 5,
#          (3709, 'Shrivastava'): 5,
#          (11498, 'Sattar'): 5,
#          (21345, 'Suresh'): 5,
#          (13017, 'México'): 5,
#          (14350, 'Natan'): 5,
#          (11123, 'Marisol'): 5,
#          (18653,
#           'https://public.tableau.com/app/profile/eeshan2538/viz/ShipStatus_1621016367480'): 5,
#          (11240, 'APKAJLTNE6QMUY6HBC5A'): 5,
#          (16299, 'Perez'): 5,
#          (7137,
#           'https://www.google.com/url?sa=i&url=http%3A%2F%2Fwww.workem.com%2Findex.php%2Fbl'): 5,
#          (21623, 'Jenny'): 5,
#          (10251, '-'): 5,
#          (7537, 'Elizabeth'): 5,
#          (13563, 'Jeremy'): 5,
#          (12184, 'Chiara'): 5,
#          (18256, 'Brenda'): 5,
#          (7779, 'Leroy'): 5,
#          (17035, 'https://fujifilm.com/fbglobal/eng/common/privacy_policy'): 5,
#          (1290, '14'): 5,
#          (11308, 'Flor'): 5,
#          (7839, 'Josephine'): 5,
#          (16660, 'David'): 5,
#          (13607, 'Sarkar'): 5,
#          (22037, 'Joe'): 5,
#          (12295, 'David'): 5,
#          (3351, 'castanedagabriel'): 5,
#          (13017, ','): 5,
#          (5433, 'Edith'): 5,
#          (15319, 'Parker'): 5,
#          (18707, 'Sebastien'): 5,
#          (18142, 'Itaú'): 5,
#          (16024, 'https://miro.com'): 4,
#          (11841, 'CINDE'): 4,
#          (6124, ','): 4,
#          (379, 'email'): 4,
#          (13747, 'Joeran'): 4,
#          (12379, 'Restricted'): 4,
#          (8575, 'Sergei'): 4,
#          (15364, 'Anna'): 4,
#          (19231, 'Texto'): 4,
#          (5023, 'Jeff'): 4,
#          (10000, 'Relo'): 4,
#          (10077, 'Angela'): 4,
#          (3427, 'Geoff'): 4,
#          (17162, 'Mason'): 4,
#          (20022, 'Bahr'): 4,
#          (9399, 'George'): 4,
#          (6784, 'Silvia'): 4,
#          (12782, 'John'): 4,
#          (12782, 'Mary'): 4,
#          (11354, 'Hess'): 4,
#          (7858, 'http://wisemapping.com/'): 4,
#          (6600, 'Maitra'): 4,
#          (6600, 'Anirban'): 4,
#          (11388, 'DiaperXL'): 4,
#          (609, '875673967537'): 4,
#          (609, '784372734211'): 4,
#          (6537, '('): 4,
#          (15461, 'Ctgjjkkloikoklplp'): 4,
#          (15461, 'Gcjludykajwhemhliiduhjj'): 4,
#          (15461, 'azxvghvmvcfxd'): 4,
#          (4115, 'Madrid'): 4,
#          (9957, 'Frey'): 4,
#          (9146, 'StuDocu'): 4,
#          (2651, 'Paul'): 4,
#          (12267, '<'): 4,
#          (19411, 'jfjg'): 4,
#          (5855, 'Korea'): 4,
#          (21514, 'Saeid'): 4,
#          (6282, 'Guzman'): 4,
#          (9289, 'André'): 4,
#          (6611, '\u200bhttps://poetrydispatch.wordpress.com/2007/10/24'): 4,
#          (8316, 'ENEA'): 4,
#          (7137, 'vfe&ved=0CAIQjRxqFwoTCODK7paehu0CFQAAAAAdAAAAABAJ'): 4,
#          (12090, 'http://www-rohan.sdsu.edu/~digger/305/toulmin_model.htm'): 4,
#          (14277, 'Miguel'): 4,
#          (20763, 'Gottschall'): 4,
#          (9578, 'Bussiness'): 4,
#          (17330, 'Durand'): 4,
#          (17330, 'Diane'): 4,
#          (3709, 'Hamid'): 4,
#          (14781, 'Abeer'): 4,
#          (12512, 'Purdue'): 4,
#          (4094, 'https://interaffairs.ru/news/show/25416'): 4,
#          (17341, 'sc1'): 4,
#          (11864, 'Narayan'): 4,
#          (14643, 'Luis'): 4,
#          (13144, '.'): 4,
#          (20531, 'Rajashekara'): 4,
#          (12458, 'Jaralee'): 4,
#          (21071,
#           'https://www.axelos.com/CMSPages/GetFile.aspx?guid=cbf5524d-2d6b-4ac9-ad5c-'): 4,
#          (3709, 'Prasad'): 4,
#          (21071, 'c0e1bd6e2899'): 4,
#          (21425, 'https://www.axure.com/'): 4,
#          (2651, 'de'): 4,
#          (5319, 'Jj'): 4,
#          (17330, 'Safiyah'): 4,
#          (9115, 'Jay'): 4,
#          (17330, 'Khairah'): 4,
#          (9115, 'Johnson'): 4,
#          (20, 'Geoff'): 4,
#          (12653, 'Ryan'): 4,
#          (22655, 'George'): 4,
#          (20047, 'Mr.'): 4,
#          (22655, 'Geoff'): 4,
#          (11781, 'Angela'): 4,
#          (10078, 'Norman'): 4,
#          (9847, 'Luna'): 4,
#          (9847, 'Preet'): 4,
#          (6194, 'Maersk'): 4,
#          (22124, 'Luke'): 4,
#          (14714, 'JP'): 4,
#          (9460, 'Jose'): 4,
#          (20921, 'Aranya'): 4,
#          (14714, 'Phillips'): 4,
#          (13563, 'Alexis'): 4,
#          (20539, 'Vaidya'): 4,
#          (20539, 'Abhay'): 4,
#          (2790, 'Geoff'): 4,
#          (5037, 'Heiko'): 4,
#          (11289, 'Ramtin'): 4,
#          (12055, 'see'): 4,
#          (18256, 'Mata'): 4,
#          (6194, 'Moller'): 4,
#          (333, '05'): 4,
#          (9110,
#           'https://www.youtube.com/watch?v=t3kKechcwYM&feature=emb_title'): 4,
#          (3603, 'Avion'): 4,
#          (10324, 'Safiyah'): 4,
#          (10938, 'Arab'): 4,
#          (11896, 'Taylor'): 4,
#          (15749, 'Fatima'): 4,
#          (15749, 'Rosas'): 4,
#          (16660, 'Nehemiah'): 4,
#          (21722,
#           'https://issuu.com/cpitrade/docs/broadcast_pro_march_2021'): 4,
#          (9621, 'Angelica'): 4,
#          (609, 'Swetha'): 4,
#          (14462, 'Kaya'): 4,
#          (12429, 'Packaging'): 4,
#          (10289, 'Thanks'): 4,
#          (9405, 'Fabrizio'): 4,
#          (10873, 'Jamar'): 4,
#          (6537, ')'): 4,
#          (379, ','): 4,
#          (10483, 'Sandrine'): 4,
#          (14462, 'Joachim'): 4,
#          (9263, 'Bora'): 4,
#          (5896, ':'): 3,
#          (20809, 'Stort'): 3,
#          (18398, 'www.DeepL.com/Translator'): 3,
#          (11461, 'Asian'): 3,
#          (20503, 'Sellection'): 3,
#          (13603, 'Angela'): 3,
#          (18226, 'Michellin'): 3,
#          (13236, 'Morales'): 3,
#          (13236, 'Maritza'): 3,
#          (20757, 'Rizan'): 3,
#          (8302, '2'): 3,
#          (5688, 'a'): 3,
#          (5688, 'e'): 3,
#          (5688, 'g'): 3,
#          (11407, 'Iam'): 3,
#          (13627, 'https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1502210/'): 3,
#          (8296, 'Angela'): 3,
#          (9533, 'Mochi'): 3,
#          (1810, 'Lorena'): 3,
#          (14267, 'Gene'): 3,
#          (5023, 'Bezos'): 3,
#          (11354, 'Ahmed'): 3,
#          (10057, 'Leche'): 3,
#          (14267, 'Carr'): 3,
#          (10057, 'Pascual'): 3,
#          (8344, 'Anna'): 3,
#          (11714, 'Eze'): 3,
#          (14267, 'Davis'): 3,
#          (11714, 'Berger'): 3,
#          (14267, 'versoco.com'): 3,
#          (6999, ':'): 3,
#          (4717, 'Qais'): 3,
#          (15461, 'Sevghjkjllkko'): 3,
#          (15461, ','): 3,
#          (10974, 'Dawid'): 3,
#          (18008, 'Carmen'): 3,
#          (18226, 'Tammy'): 3,
#          (11770, 'Leonetti'): 3,
#          (15736, 'Silko'): 3,
#          (5688, 'P'): 3,
#          (11343, 'Uddin'): 3,
#          (5060, 'Fitri'): 3,
#          (2651, 'Burgess'): 3,
#          (379, 'Washington'): 3,
#          (6353, 'Savitribai'): 3,
#          (2335, 'Vizualitation'): 3,
#          (4971, '167695383458'): 3,
#          (8875, 'Rohan'): 3,
#          (2828, '1'): 3,
#          (5249, 'Raxa'): 3,
#          (17326, 'pproach'): 3,
#          (22071, 'Pratchett'): 3,
#          (20989, 'Paul'): 3,
#          (9493, 'Person'): 3,
#          (6537, 'Zahida'): 3,
#          (13193, 'Charlie'): 3,
#          (9578, 'Proyect'): 3,
#          ...})

# %%
fn_counter
# Out:
# Counter({(3241, 'Rodriguez'): 119,
#          (6117, 'Sharma'): 106,
#          (6117, 'Hari'): 104,
#          (9911, 'Mpanza'): 104,
#          (9911, 'Cobus'): 103,
#          (7779, 'Leroy'): 101,
#          (10517, 'ras21'): 97,
#          (12077, 'Daniel'): 95,
#          (9854, '\n'): 95,
#          (4351, 'Nazri'): 92,
#          (7779, 'Sullivan'): 91,
#          (12585, 'Art'): 88,
#          (12585, 'Street'): 88,
#          (4351, 'Marta'): 88,
#          (6148, 'Christian'): 88,
#          (9674, 'Princess'): 87,
#          (4351, 'Sin'): 87,
#          (12077, 'Kate'): 86,
#          (12330, 'Miriam'): 86,
#          (4351, 'Ivan'): 85,
#          (3885, 'Irina'): 84,
#          (4161, 'Ashley'): 83,
#          (8798, 'Roberta'): 82,
#          (12512, 'Jordi'): 82,
#          (9324, 'Menna'): 81,
#          (8747, 'Nandan'): 81,
#          (11208, 'Suarez'): 81,
#          (20984, 'V69230'): 78,
#          (3885, 'Luca'): 75,
#          (9920, 'Muhammad'): 75,
#          (9286, 'Prakash'): 75,
#          (4922, 'Tam'): 74,
#          (11442, '\n'): 74,
#          (3214, 'Ashley'): 74,
#          (9974, 'Birra'): 70,
#          (4922, 'Fatin'): 68,
#          (9974, 'Virginia'): 68,
#          (6694, 'Jose'): 68,
#          (8139, 'Stephen'): 68,
#          (4094, 'Ine'): 67,
#          (11288, 'Juan'): 67,
#          (9974, 'Carrasco'): 66,
#          (13249, 'David'): 66,
#          (9405, 'Fabrizio'): 65,
#          (9974, 'Jeff'): 64,
#          (5215, 'Kumari'): 63,
#          (19280, 'Z.S.'): 63,
#          (9043, 'Manuela'): 62,
#          (1105, 'Fatima'): 61,
#          (5902, 'Karen'): 61,
#          (9760, 'Md'): 59,
#          (4094, 'Leo'): 58,
#          (2722, 'Saman'): 57,
#          (9535, 'Liliana'): 56,
#          (9801, 'Mostafa'): 56,
#          (4574, 'Annie'): 56,
#          (9590, 'https://youtu.be/AsSLvOLkUYn'): 55,
#          (6007, 'https://www.youtube.com/watch?v=2sOzgGAeiQV'): 55,
#          (12456, 'https://www.youtube.com/watch?v=x5Y6nYsYmtA'): 55,
#          (6557, 'Luca'): 54,
#          (9760, 'Bk'): 53,
#          (9387, 'Johana'): 52,
#          (10057, 'https://www.youtube.com/watch?v=2W2A1l98qVg'): 51,
#          (9365, 'Vincenzo'): 51,
#          (11319, 'Noora'): 50,
#          (9493, 'Junaid'): 50,
#          (10693, 'Schuster'): 50,
#          (9801, 'Kamlesh'): 49,
#          (7993, 'Quentin'): 48,
#          (11319, 'Ricardo'): 47,
#          (12456, 'https://www.youtube.com/watch?v=jhw3sb6ZCAZ'): 47,
#          (204, 'Deiby'): 47,
#          (13249, 'Cristiane'): 46,
#          (4351, 'Liz'): 46,
#          (4351, 'Okey'): 46,
#          (11564, 'Yara'): 45,
#          (11208, 'Santiago'): 45,
#          (11566, 'Emily'): 45,
#          (8718, 'Teresa'): 43,
#          (9018, 'Felice'): 43,
#          (4323, 'Mohammed'): 43,
#          (2700, 'https://www.youtube.com/watch?v=n-ajTPJ1h-J'): 42,
#          (9854, 'https://www.youtube.com/watch?v=tIBN9VJ0S4a'): 42,
#          (8718, 'Naser'): 41,
#          (10693, 'Peter'): 41,
#          (8340, 'El'): 41,
#          (9050, 'Youssef'): 40,
#          (3202, 'nYZqnhEXw'): 40,
#          (6457, 'https://www.youtube.com/watch?v=tQSdE32O5KE'): 39,
#          (6426, 'https://www.youtube.com/watch?v=EnVUhYZvCFr'): 35,
#          (8108, 'Sameh'): 35,
#          (9146, 'nMFtUVxSUI|33529258'): 35,
#          (9493, 'Stella'): 35,
#          (6426, 'https://www.youtube.com/watch?v=e2D2mFcZzeW'): 34,
#          (11073, 'Kim'): 33,
#          (12852, 'Momentos'): 33,
#          (15717, 'IV-8322'): 31,
#          (11566, 'Giuseppe'): 31,
#          (10672, 'Dip'): 28,
#          (7680, 'http://www.tate.com/'): 27,
#          (9799, 'Sajjad'): 27,
#          (9297, 'https://www.youtube.com/watch?v=y1ZQmZmkaDD'): 26,
#          (2722, 'Mojica'): 26,
#          (9421, 'http://www.moore.com/'): 24,
#          (8762, 'Marwa'): 24,
#          (12184, 'Chiara'): 24,
#          (9365, 'Mondal'): 24,
#          (5215, 'Matheus'): 22,
#          (9289, 'Khan'): 22,
#          (12154, 'https://youtu.be/Kb-hqNGr5lJ'): 21,
#          (10418, 'https://www.youtube.com/watch?v=B131Tm9Iex1'): 21,
#          (5855, 'Sutton'): 20,
#          (9297, 'https://www.youtube.com/watch?v=HePCiQaZo2X'): 20,
#          (12120, 'Huerta'): 19,
#          (11900, 'Benjamin'): 19,
#          (136, 'Al'): 19,
#          (8340, 'Petrosillo'): 19,
#          (5855, 'May'): 18,
#          (8344, 'Janet'): 18,
#          (8909, 'https://youtu.be/bDPejFHJSsT'): 18,
#          (8480, 'Nada'): 17,
#          (5023, 'Iz.:999893751750'): 17,
#          (3351, 'castanedagabriel'): 17,
#          (3709, 'Johnson'): 17,
#          (5811, 'Federica'): 17,
#          (10595, 'White'): 17,
#          (12154, 'https://youtu.be/1pM3sb7AMPs'): 17,
#          (12120, 'Benjamin'): 16,
#          (11073, 'Steffen'): 16,
#          (9760, 'Sama'): 15,
#          (4868, 'Francois'): 15,
#          (9289, 'Gabriele'): 15,
#          (6622, 'Yates'): 15,
#          (6622, 'John'): 15,
#          (10829, 'Dawn'): 14,
#          (3202, 'https://www.youtube.com/channel/UC1ElAcppeuhfet'): 14,
#          (7745, 'Daniel'): 14,
#          (13103, 'https://hernandez.com/exploremain.html'): 14,
#          (10024, 'https://youtu.be/h9YTxzr_HPS'): 14,
#          (6784, 'https://soto.com/listregister.asp'): 14,
#          (10376, 'Rivera'): 14,
#          (10131, 'Perez'): 13,
#          (2828, 'James'): 13,
#          (10595, 'Stephen'): 13,
#          (2828, 'Gray'): 13,
#          (4868, 'Rita'): 13,
#          (8379, 'Juric'): 13,
#          (10376, 'Eva'): 13,
#          (11900, 'Maria'): 12,
#          (5964, 'Karla'): 12,
#          (8127, 'Filip'): 12,
#          (7733, 'https://www.cuevas.info/blogsearch.html'): 12,
#          (8674, 'Kalu'): 12,
#          (609, 'Bravo'): 11,
#          (609, 'Hlengiwe'): 11,
#          (8480, 'Ahmed'): 11,
#          (19280, '30407059'): 11,
#          (5322, 'Richards'): 11,
#          (11128, 'Bergamo'): 11,
#          (9281, 'Cherie'): 11,
#          (9281, 'Gray'): 11,
#          (5380, 'Watson'): 11,
#          (8674, 'Abdul'): 10,
#          (11128, 'Pasquale'): 10,
#          (13121, 'Junior'): 10,
#          (8379, 'Iva'): 10,
#          (5380, 'Chiara'): 10,
#          (609, '530670102508'): 9,
#          (11529, 'Raph'): 9,
#          (12634, 'Sales'): 9,
#          (9636, 'Gonzalez'): 9,
#          (10617, 'http://www.bonilla.org/category/tags/wp-contentfaq.htm'): 9,
#          (4650, 'Marco'): 9,
#          (5322, 'Enzo'): 9,
#          (10672, 'Ari'): 9,
#          (472, 'https://youtu.be/rFD2lJuvace'): 9,
#          (609, 'Alex'): 8,
#          (10131, 'Miguel'): 8,
#          (6064, 'Silvia'): 8,
#          (4214, 'Moreno'): 8,
#          (12120, 'Elisangela'): 8,
#          (11308, 'Flor'): 8,
#          (11421, 'Melnik'): 8,
#          (7, 'Sylla'): 8,
#          (9394, 'Rupesh'): 8,
#          (10448, '027693'): 8,
#          (5561, 'Starks'): 7,
#          (13103, 'https://www.roman.info/list/appindex.html'): 7,
#          (4214, 'Alvaro'): 7,
#          (12462, 'Ton'): 7,
#          (12184, 'Kumar'): 7,
#          (609, 'Swetha'): 6,
#          (7156, 'DM:705244534902'): 6,
#          (6976, 'Kings'): 6,
#          (4709, 'Angela'): 6,
#          (8095, 'Gary'): 6,
#          (11421, 'Borz'): 6,
#          (9543, 'Thulani'): 6,
#          (4899, 'Panagiotopoulou'): 6,
#          (3885, 'Leonardo'): 6,
#          (11719, 'Maxim'): 6,
#          (324, 'Zia'): 6,
#          (9394, 'Kumar'): 6,
#          (7645, 'Francesco'): 6,
#          (7003, 'Patrick'): 6,
#          (9460, 'King'): 6,
#          (1277, 'Mahi'): 6,
#          (1277, 'Vicki'): 6,
#          (4650, 'Vincenzo'): 5,
#          (12184, 'Pintu'): 5,
#          (12184, 'Ajay'): 5,
#          (4777, 'Fatma'): 5,
#          (4351, 'Tyler'): 5,
#          (13121, 'Wallace'): 5,
#          (7708, 'Daniela'): 5,
#          (9460, 'Jose'): 5,
#          (9394, 'Ahmad'): 5,
#          (8192, 'Hasan'): 5,
#          (9460, 'David'): 5,
#          (9760, '347376430553'): 4,
#          (1763, 'Imtiyaz'): 4,
#          (609, '557349702179'): 4,
#          (609, '860632713425'): 4,
#          (609, '875673967537'): 4,
#          (9636, 'Stephanie'): 4,
#          (9336, 'Antonio'): 4,
#          (9336, 'Hanson'): 4,
#          (6976, 'Ifeoma'): 4,
#          (11745, 'Barco'): 4,
#          (11399, 'Islam'): 4,
#          (7680, 'Jonathan'): 4,
#          (7203, 'Juan'): 4,
#          (7000, 'https://ingram-castro.com/tagsmain.html'): 4,
#          (9460, 'Lupe'): 4,
#          (3709, 'Katia'): 4,
#          (3709, 'Denis'): 4,
#          (9760, 'Giuseppe'): 4,
#          (12443, 'Ahmed'): 4,
#          (8480, 'Mohamed'): 4,
#          (4650, 'Reshma'): 4,
#          (5023, 'Kl.:838901042770'): 4,
#          (11883,
#           'http://www.stokes.com/wp-content/main/searchregister.htm'): 4,
#          (2732, 'Sunny'): 4,
#          (5263, 'Dla'): 4,
#          (5263, 'Xalid'): 4,
#          (4971, '943063077874'): 3,
#          (1798, 'Neha'): 3,
#          (8575, 'Maga'): 3,
#          (7006, 'Angelik'): 3,
#          (8714, 'Jamshed'): 3,
#          (10220, 'Garcia'): 3,
#          (8416, 'http://martin.com/app/tags/searchregister.php'): 3,
#          (5060, 'Nor'): 3,
#          (5561, 'Karina'): 3,
#          (4717, '186941941714'): 3,
#          (2915, 'Gomez'): 3,
#          (12397, 'Md'): 3,
#          (12154, 'http://www.jackson.com/appcategory.html'): 3,
#          (1105, 'Molina'): 3,
#          (9535, 'Clark'): 3,
#          (11900, 'Das'): 3,
#          (6537, 'Vishwkarma'): 3,
#          (9460, 'Luis'): 3,
#          (7236, 'Alberto'): 3,
#          (6220, 'Alison'): 3,
#          (7, 'Nathalie'): 3,
#          (609, '784372734211'): 3,
#          (3202, 'tps://www.facebook.com/bclark'): 3,
#          (1802, 'Ilir'): 3,
#          (13311, 'Luis'): 3,
#          (609, 'Lopez'): 3,
#          (12558, 'Fernando'): 3,
#          (4913, 'Sana'): 3,
#          (6171, 'Serafini'): 3,
#          (7203, 'Bakker'): 3,
#          (10617, 'http://www.green.info/wp-content/wp-contentpost.html'): 3,
#          (9665,
#           'https://www.bell-kelly.net/tag/tags/categoriesprivacy.htm'): 3,
#          (7680, 'Vieira'): 3,
#          (12184, '320622779078'): 3,
#          (12812, 'Cruz'): 3,
#          (12812, 'Mohamed'): 3,
#          (269, 'Claudia'): 3,
#          (269, 'Sarria'): 3,
#          (10472, 'Cardo'): 3,
#          (10472, 'Dalisay'): 3,
#          (4094, 'Rosa'): 3,
#          (4094, 'Perna'): 3,
#          (10093, 'Saidi'): 3,
#          (10093, 'Olivier'): 3,
#          (13115, 'Rolando'): 3,
#          (13115, 'Martinez'): 3,
#          (5271, 'Arias'): 3,
#          (10, 'Diego'): 3,
#          (8642, 'Basavaraju'): 3,
#          (4971, 'Khan'): 3,
#          (10724, 'Ankit'): 2,
#          (8699, 'Rosli'): 2,
#          (10934, 'Sunday'): 2,
#          (4669, 'Shamim'): 2,
#          (12184, 'Rana'): 2,
#          (12184, 'Md'): 2,
#          (14484, 'hbrown@yahoo.com'): 2,
#          (10617, 'https://www.shaw-smith.net/tags/listfaq.html'): 2,
#          (6665, 'Salinas'): 2,
#          (6694, 'Ahmad'): 2,
#          (8302, 'Shahed'): 2,
#          (1325, 'Der'): 2,
#          (8642, 'holmespatrick'): 2,
#          (10164, 'Mendes'): 2,
#          (8880, 'Salma'): 2,
#          (5236, 'Rashmi'): 2,
#          (11745, 'Valeri'): 2,
#          (10880, 'Leslie'): 2,
#          (8192, 'Roberto'): 2,
#          (10880, 'Young'): 2,
#          (609, '674915248960'): 2,
#          (1802, 'Ahmed'): 2,
#          (1798, 'Sharma'): 2,
#          (3709, 'https://diaz.com/tag/wp-contentlogin.htm'): 2,
#          (5060, 'Fitri'): 2,
#          (10281, 'Bezuidenhout'): 2,
#          (4816, 'Teresa'): 2,
#          (8575, 'Ivanova'): 2,
#          (5083,
#           'http://www.chambers.com/wp-content/app/categorieshomepage.jsp'): 2,
#          (6171, 'Alexandra'): 2,
#          (7745, 'Nowak'): 2,
#          (609, 'Tino'): 2,
#          (6999, 'VZ:775Y6A5764'): 2,
#          (295, 'Zhe'): 2,
#          (299, 'Rodriguez'): 2,
#          (379, 'David'): 2,
#          (122, 'Ton'): 2,
#          (379, 'Cristiane'): 2,
#          (242, 'Marwa'): 2,
#          (296, 'https://www.price.info/categories/search/tagprivacy.htm'): 2,
#          (78, 'http://www.stokes.com/wp-content/main/searchregister.htm'): 2,
#          (392, 'Mohammed'): 2,
#          (225, 'Vincenzo'): 2,
#          (236, 'Nandan'): 2,
#          (9540, 'Jan'): 2,
#          (11900, 'Lisa'): 2,
#          (12184, 'Ahamad'): 2,
#          (9760, '943995368223'): 2,
#          (9460, 'Rubin'): 2,
#          (5167, 'Cherry'): 2,
#          (5167, 'Dantas'): 2,
#          (5271, 'Luna'): 2,
#          (7262, 'Steve'): 2,
#          (7262, 'Hernandez'): 2,
#          (5796, 'Vw.:403489591437'): 2,
#          (9433, 'Brenda'): 2,
#          (13311, 'Jose'): 2,
#          (5935, 'Mohamad'): 2,
#          (13311, 'Llamas'): 2,
#          (4899, 'Maria'): 2,
#          (1295, 'Polidori'): 2,
#          (3882, 'Sanam'): 2,
#          (3882, 'Khan'): 2,
#          (16, 'Gamboa'): 2,
#          (16, 'Gilberto'): 2,
#          (12852, 'Hector'): 2,
#          (10522, 'Russo'): 2,
#          (10522, 'Jayanti'): 2,
#          (9801, 'https://www.brooks.net/exploreprivacy.html'): 2,
#          (3892, 'Ka'): 2,
#          (3892, 'Joyce'): 2,
#          (5192, 'Laurent'): 2,
#          (5192, 'Isabelle'): 2,
#          (6378, 'Waseem'): 2,
#          (6378, 'Hamad'): 2,
#          (10214, 'Fernando'): 2,
#          (10214, 'Roversi'): 2,
#          (8316, 'Angela'): 2,
#          (3987, 'Tara'): 2,
#          (6243, '('): 2,
#          (6088, 'Bock'): 1,
#          (8894, 'Garcia'): 1,
#          (11806, 'Ali'): 1,
#          (7156, '789323889085'): 1,
#          (7156, '132305666219'): 1,
#          (8962, 'Putino'): 1,
#          (12043, 'http://osborne.org/main/posts/tagprivacy.asp'): 1,
#          (12043, 'http://thomas.biz/list/taghome.php'): 1,
#          (2915, 'Carolina'): 1,
#          (6665, 'Sonia'): 1,
#          (12087, 'Jan'): 1,
#          (6853, 'https://www.linkedin.com/in/michael16'): 1,
#          (12154, 'https://glenn.org/postsindex.jsp'): 1,
#          (9358, 'http://hensley.info/exploreabout.jsp'): 1,
#          (5287, 'Perez'): 1,
#          (5287, 'Alex'): 1,
#          (5236, 'Vipan'): 1,
#          (9348, 'Parker'): 1,
#          (9348, 'Greg'): 1,
#          (7197, 'Wilma'): 1,
#          (7197, 'Dekker'): 1,
#          (5116, 'Perle'): 1,
#          (5116, 'Kamdem'): 1,
#          (10561, 'Fabian'): 1,
#          (10561, 'Silvera'): 1,
#          (6537, 'Ajay'): 1,
#          (12397, 'Sobuj'): 1,
#          (6517, 'Danielle'): 1,
#          (6517, 'West'): 1,
#          (8690, 'Diego'): 1,
#          (609, '054176622314'): 1,
#          (10164, 'Rui'): 1,
#          (5606, 'Emanuela'): 1,
#          (4158, 'Rehab'): 1,
#          (6497, 'Indhumathi'): 1,
#          (6027, 'Laterza'): 1,
#          (6808, 'Amritpal'): 1,
#          (3586, 'Bellafiore'): 1,
#          (3935, 'Ismael'): 1,
#          (8435, 'Dai'): 1,
#          (1210, 'David'): 1,
#          (5606, 'Kh:360595695159'): 1,
#          (5606, 'Kh:217952887271'): 1,
#          (4913, 'Asmaa'): 1,
#          (8688, 'https://vargas.com/list/exploreauthor.html'): 1,
#          (5606, 'Un:705491035775'): 1,
#          (8229, 'Mazzoleni'): 1,
#          (10945, 'https://www.price.info/categories/search/tagprivacy.htm'): 1,
#          (9460, 'Anjali'): 1,
#          (8842, 'Guido'): 1,
#          (7293, 'Den'): 1,
#          (6537, 'Zahida'): 1,
#          (25, 'http://www.olsen.org/posts/blog/searchabout.html'): 1,
#          (25, 'https://www.shaw-smith.net/tags/listfaq.html'): 1,
#          (293, 'Fernando'): 1,
#          (12483, 'Weyhacy_7000693584'): 1,
#          (11900, 'Bikram'): 1,
#          (7730, 'Sergio'): 1,
#          (4684, 'Abdul'): 1,
#          (7730, 'Camilo'): 1,
#          (4684, 'Vassallo'): 1,
#          (9422, 'Thea'): 1,
#          (4744, 'Busisiwe'): 1,
#          (12184, 'Taher'): 1,
#          (13144, 'Sarah'): 1,
#          (13144, 'Roberto'): 1,
#          (9892, 'http://www.jackson.com/categories/search/tagsmain.html'): 1,
#          (11428, 'http://camacho.biz/blog/main/appfaq.jsp'): 1,
#          (9892, 'https://www.smith-flores.com/mainlogin.htm'): 1,
#          (11900, '534516353860'): 1,
#          (11900, '723847538279'): 1,
#          (11900, '871483046449'): 1,
#          (13317, 'Oscar'): 1,
#          (9470, 'https://brown.info/posts/searchauthor.php'): 1,
#          (12791, 'Marc'): 1,
#          (11376, 'Cesar'): 1,
#          (10617, 'http://www.olsen.org/posts/blog/searchabout.html'): 1,
#          (9297, 'https://www.youtube.com/user/vdrake'): 1,
#          (11564, 'Cruz'): 1,
#          (6416, 'Juan'): 1,
#          (6416, 'Velasquez'): 1,
#          (9540, 'Miah'): 1,
#          (3328, 'Karim'): 1,
#          (3328, 'Elnazer'): 1,
#          (6694, 'Kumar'): 1,
#          (13315, 'https://alvarado.com/categoriesindex.html'): 1,
#          (11461, 'Paredes'): 1,
#          (9473, 'Pimienta'): 1,
#          (9473, 'Amparo'): 1,
#          (9433, 'Garcia'): 1,
#          (10769, 'Nurul'): 1,
#          (10617, 'http://www.barry.com/main/list/postshomepage.html'): 1,
#          (12184, '264945858442'): 1,
#          (3736, 'Pandey'): 1,
#          (10620, 'Saravanan'): 1,
#          (9653, 'Man'): 1,
#          (10, 'Estrada'): 1,
#          (12132, 'Shepherd'): 1,
#          (12132, 'Becky'): 1,
#          (11975, 'Lim'): 1,
#          (3915, 'Laitinen'): 1,
#          (3427, 'Rhiannon'): 1,
#          (4070, 'Mary'): 1,
#          (4070, 'Mohamed'): 1,
#          (10609, 'http://www.chapman-robinson.com/explorelogin.htm'): 1,
#          (5069, '06EYD876'): 1,
#          (6124, 'Victoria'): 1,
#          (6124, 'Horton'): 1,
#          (11165, 'Fofa'): 1,
#          (11165, 'Bravo'): 1,
#          (4521, 'Lara'): 1,
#          (4521, 'Gabriel'): 1,
#          (12803, 'Ahmed'): 1,
#          (6591, 'Dubey'): 1,
#          (12307, 'Levi'): 1,
#          (12307, 'Liron'): 1,
#          (12248, 'Daniel'): 1,
#          (3565, 'Saponara'): 1,
#          (4462, 'fdixon'): 1,
#          (8316, 'Torres'): 1,
#          (56, 'Born'): 1,
#          (12564, 'https://www.linkedin.com/feevanessacook'): 1,
#          (3987, 'Limbu'): 1,
#          (4971, '792389774673'): 1,
#          (4971, '167695383458'): 1,
#          (6591, '276795361801'): 1})

# %%
fp_df = pd.DataFrame(fp_info, columns=["label_pred", "token", "document", "token_text_pred"])
fp_df
# Out:
#             label_pred  token  document   token_text_pred
# 0       I-NAME_STUDENT    352     20449             Riley
# 1       I-NAME_STUDENT    566     15749             Rosas
# 2       B-NAME_STUDENT    614     12267                BP
# 3           I-USERNAME    255     18270                 ​
# 4       B-NAME_STUDENT    805     11376             Fabio
# ...                ...    ...       ...               ...
# 3703    B-NAME_STUDENT      0     21538              Alex
# 3704    B-URL_PERSONAL    261      9117  https://otter.ai
# 3705  I-STREET_ADDRESS      8       121                 ,
# 3706    B-NAME_STUDENT    921     21316              Mike
# 3707    B-NAME_STUDENT    171     13008             Geoff
#
# [3708 rows x 4 columns]
